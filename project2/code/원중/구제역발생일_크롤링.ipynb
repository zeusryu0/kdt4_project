# %%
## 2. 구제역 병인체
# Picornaviridae Aphthovirus,작은 RNA 바이러스로서 이는 7개의 혈청형 즉 A, O, C, Asia1, SAT1, SAT2, SAT3형으로 분류되며 
# 이 주요 혈청형은 다시 80여 가지의 아형으로 나뉨. 바이러스의 생존기간은 온도, 습도, pH 및 자외선 등에 영향을 많이 받으며, 
# 통상 물에서는 최대 50일, 흙‧마대‧건초 등에서는 환경조건에 따라서 26~200일, 
# 혈액 등으로 오염된 나무나 금속 등에서는 최대 35일까지 생존한 기록이 있음.

# * 온도, 습도, pH 및 자외선 (ph는 측정불가)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
import time

# %%
url = 'https://www.kahis.go.kr/home/lkntscrinfo/selectLkntsOccrrncList.do'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser' )
# soup.text

# %%
# 전체 테이블
soup.select('tr > td > table')
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" class="font_height18" style="margin-top:15px; margin-right:15px; margin-bottom:15px; margin-left:15px; " width="100%">
#  <tr>
#  <td>□ 공개 근거 : 가축전염병예방법 제3조의2 및 같은 법 시행령 제2조의2<br/>
#                                 ○ 가축전염병을 예방하고 그 확산을 방지하기 위하여 농장에 대한 가축전염병 발생 일시 및 농장명 등을 공개<br/>
#                                 ○ 공개 대상 가축전염병 : 구제역, 돼지열병, 돼지오제스키병, 돼지생식기호흡기 증후군, 브루셀라병, 결핵병, <br/>
#                                                                     고병원성조류인플루엔자, 추백리, 가금티푸스, 뉴캣슬병, 사슴만성소모성질병, 낭충봉아부패병, 아프리카돼지열병<br/>
#                                 ○ 공개 대상 가축 : 소, 산양, 면양, 돼지, 닭, 사슴, 오리, 거위, 칠면조, 메추리 <br/><br/>
#                              ※ 발생현황 정보는 시·도 가축방역기관 등 가축질병 병성감정기관의 가축전염병 발생보고를 바탕으로 제공하고 있으며, <br/>    상기 목적 외 해당 정보의 사용을 금함<br/>
#                              ※ 발생두수는 가축전염병 통계확정 전 까지 변동될 수 있음
#                              <br/>※ 낭충봉아부패병은 2017년 09월 22일 자료부터 조회가능합니다. <br/></td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" style="margin-top:0px; margin-right:0px; margin-bottom:0px; margin-left:10px;">
#  <tr>
#  <td class="search" height="22"><img alt="dot아이콘" height="9" src="/images/dpl/img/ico_text_dot01.gif" width="14"/>조회기간</td>
#  <td width="5"> </td>
#  <td><label><input checked="checked" id="turmGubun1" name="turmGubun" type="radio" value="01"/>진단일</label></td>
#  <td width="10"></td>
#  <td><label><input id="turmGubun2" name="turmGubun" type="radio" value="02"/>발생일</label></td>
#  <td width="10"></td>
#  <td><input alt="검색창" class="input" id="occrFromDtId" name="occrFromDt" onblur="onBlurFormatDate(this)" onfocus="onFocusFormatDate(this)" size="10" title="검색창" type="text" value="2021-03-04"/></td>
#  <td width="2"> </td>
#  <td align="center" width="10">-</td>
#  <td><input alt="검색창" class="input" id="occrToDtId" name="occrToDt" onblur="onBlurFormatDate(this)" onfocus="onFocusFormatDate(this)" size="10" title="검색창" type="text" value="2022-03-04"/></td>
#  <td width="2"> </td>
#  <td width="15"> </td>
#  <td class="search">   <img alt="dot아이콘" height="9" src="/images/dpl/img/ico_text_dot01.gif" width="14"/>질병명</td>
#  <td width="5"> </td>
#  <td><label>
#  <select class="input" id="dissCl" name="dissCl">
#  <option value="">전체</option>
#  <option value="0007">가금티푸스</option>
#  <option value="0099">결핵병</option>
#  <option value="0111">고병원성 조류인플루엔자</option>
#  <option value="0191">구제역</option>
#  <option value="0333">뉴캣슬병</option>
#  <option value="0406">돼지생식기호흡기증후군</option>
#  <option value="0412">돼지열병</option>
#  <option value="0418">돼지오제스키병</option>
#  <option value="0504">사슴만성소모성질병</option>
#  <option value="0683">브루셀라병</option>
#  <option value="1442">추백리</option>
#  <option value="0296">낭충봉아부패병</option>
#  <option value="1003">아프리카돼지열병</option>
#  </select>
#  </label>
#  </td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" style="margin-top:0px; margin-right:0px; margin-bottom:0px; margin-left:10px;">
#  <tr>
#  <td class="search"><img alt="dot아이콘" height="9" src="/images/dpl/img/ico_text_dot01.gif" width="14"/>지역선택</td>
#  <td width="5"> </td>
#  <td>
#  <div id="ajaxLegaldong">
#  <label>
#  <select class="input" id="ctprvn" name="ctprvn" onchange="ajaxLegaldong('ctprvn');" style="width:100px;">
#  <option value=" ">전체</option>
#  <option value="11">서울특별시</option>
#  <option value="26">부산광역시</option>
#  <option value="27">대구광역시</option>
#  <option value="28">인천광역시</option>
#  <option value="29">광주광역시</option>
#  <option value="30">대전광역시</option>
#  <option value="31">울산광역시</option>
#  <option value="36">세종특별자치시</option>
#  <option value="41">경기도</option>
#  <option value="42">강원도</option>
#  <option value="43">충청북도</option>
#  <option value="44">충청남도</option>
#  <option value="45">전라북도</option>
#  <option value="46">전라남도</option>
#  <option value="47">경상북도</option>
#  <option value="48">경상남도</option>
#  <option value="50">제주특별자치도</option>
#  </select>
#  <select class="input" id="signgu" name="signgu" onchange="ajaxLegaldong('signgu');" style="width:100px;">
#  <option value=" ">전체</option>
#  </select>
#  <!--
#                                      <select name="emd" id="emd" class="input" id="select" style="width:100px;">
#
#                                      <option value=" " >전체</option>
#
#                                      </select>
#                                      -->
#  </label>
#  </div>
#  </td>
#  <td width="5">      </td>
#  <td class="search" height="22"><img alt="dot아이콘" height="9" src="/images/dpl/img/ico_text_dot01.gif" width="14"/>축   종</td>
#  <td width="5"> </td>
#  <td><label>
#  <select class="input" id="lstkspCl" name="lstkspCl">
#  <option value="">전 체</option>
#  <option value="4120">소</option>
#  <option value="4141">산양</option>
#  <option value="4142">면양</option>
#  <option value="4130">돼지</option>
#  <option value="4150">닭</option>
#  <option value="4184">사슴</option>
#  <option value="4162">오리</option>
#  <option value="4163">거위</option>
#  <option value="4161">칠면조</option>
#  <option value="4164">메추리</option>
#  <option value="4186">벌</option>
#  </select>
#  </label></td>
#  <td width="2"> </td>
#  <td class="search"><img alt="dot아이콘" height="9" src="/images/dpl/img/ico_text_dot01.gif" width="14"/>법정전염병</td>
#  <td width="5"> </td>
#  <td><label>
#  <select class="input" id="legalIctsdGradSe" name="legalIctsdGradSe">
#  <option value="">전체</option>
#  <option value="1">1종</option>
#  <option value="2">2종</option>
#  <option value="3">3종</option>
#  </select>
#  </label></td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" style="height: 35px;" width="790px;">
#  <tr>
#  <td><table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tr>
#  <td align="center" class="list_title" width="13%">가축전염병명</td>
#  <td align="center" class="list_title" width="13%">농장명<br/>(농장주)</td>
#  <td align="center" class="list_title" width="17%">농장소재지</td>
#  <td align="center" class="list_title" width="13%">발생일자<br/>(진단일)</td>
#  <td align="center" class="list_title" width="8%">축종<br/>(품종)</td>
#  <td align="center" class="list_title" width="8%">발생두수<br/>(마리)</td>
#  <td align="center" class="list_title" width="16%">진단기관</td>
#  <td align="center" class="list_title" width="12%">종식일<!-- <br>(이동제한해제일) --></td>
#  </tr>
#  </table></td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tr>
#  <td align="center" class="list_title" width="13%">가축전염병명</td>
#  <td align="center" class="list_title" width="13%">농장명<br/>(농장주)</td>
#  <td align="center" class="list_title" width="17%">농장소재지</td>
#  <td align="center" class="list_title" width="13%">발생일자<br/>(진단일)</td>
#  <td align="center" class="list_title" width="8%">축종<br/>(품종)</td>
#  <td align="center" class="list_title" width="8%">발생두수<br/>(마리)</td>
#  <td align="center" class="list_title" width="16%">진단기관</td>
#  <td align="center" class="list_title" width="12%">종식일<!-- <br>(이동제한해제일) --></td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #ffff80;">
#  <td align="center" class="list_g_line" width="13%">결핵병</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  최대원
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">경상남도 합천군 야로면 하빈리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-25
#  (2022-02-25)</td>
#  <td align="center" class="list_g_line" width="8%">소-한우</td>
#  <td align="center" class="list_g_line1" width="8%">1</td>
#  <td align="left" class="list_g_line" width="16%">경남 북부지소</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #f3caf7;">
#  <td align="center" class="list_g_line" width="13%">고병원성조류인플루엔자</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  정진농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">경상남도 하동군 진교면 고이리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-21
#  (2022-02-22)</td>
#  <td align="center" class="list_g_line" width="8%">오리-육용오리</td>
#  <td align="center" class="list_g_line1" width="8%">-</td>
#  <td align="left" class="list_g_line" width="16%">조류인플루엔자연구진단과</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #f3caf7;">
#  <td align="center" class="list_g_line" width="13%">고병원성조류인플루엔자</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  진성농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">충청남도 논산시 연무읍 황화정리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-18
#  (2022-02-19)</td>
#  <td align="center" class="list_g_line" width="8%">오리-육용오리</td>
#  <td align="center" class="list_g_line1" width="8%">-</td>
#  <td align="left" class="list_g_line" width="16%">조류인플루엔자연구진단과</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #ffff80;">
#  <td align="center" class="list_g_line" width="13%">결핵병</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  청도축협 청도한우 1농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">경상북도 청도군 풍각면 덕양리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-18
#  (2022-02-18)</td>
#  <td align="center" class="list_g_line" width="8%">소-한우</td>
#  <td align="center" class="list_g_line1" width="8%">1</td>
#  <td align="left" class="list_g_line" width="16%">경북 동물위생시험소</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #f3caf7;">
#  <td align="center" class="list_g_line" width="13%">고병원성조류인플루엔자</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  태원농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">충청북도 진천군 이월면 삼용리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-12
#  (2022-02-14)</td>
#  <td align="center" class="list_g_line" width="8%">닭-육계</td>
#  <td align="center" class="list_g_line1" width="8%">-</td>
#  <td align="left" class="list_g_line" width="16%">조류인플루엔자연구진단과</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #f3caf7;">
#  <td align="center" class="list_g_line" width="13%">고병원성조류인플루엔자</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  류가네농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">충청북도 괴산군 장연면 조곡리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-12
#  (2022-02-13)</td>
#  <td align="center" class="list_g_line" width="8%">오리-종오리</td>
#  <td align="center" class="list_g_line1" width="8%">-</td>
#  <td align="left" class="list_g_line" width="16%">조류인플루엔자연구진단과</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #f3caf7;">
#  <td align="center" class="list_g_line" width="13%">고병원성조류인플루엔자</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  거성농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">충청남도 당진시 합덕읍 대전리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-12
#  (2022-02-13)</td>
#  <td align="center" class="list_g_line" width="8%">닭-산란계</td>
#  <td align="center" class="list_g_line1" width="8%">-</td>
#  <td align="left" class="list_g_line" width="16%">조류인플루엔자연구진단과</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #ffff80;">
#  <td align="center" class="list_g_line" width="13%">결핵병</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  구민농장
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">전라북도 김제시 금구면 서도리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-12
#  (2022-02-12)</td>
#  <td align="center" class="list_g_line" width="8%">소-한우</td>
#  <td align="center" class="list_g_line1" width="8%">11</td>
#  <td align="left" class="list_g_line" width="16%">전북 북부지소</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #ffff80;">
#  <td align="center" class="list_g_line" width="13%">결핵병</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  백은정
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">전라북도 완주군 비봉면 대치리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-11
#  (2022-02-11)</td>
#  <td align="center" class="list_g_line" width="8%">소-한우</td>
#  <td align="center" class="list_g_line1" width="8%">5</td>
#  <td align="left" class="list_g_line" width="16%">전북 동물위생시험소</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  <tr onmouseout='this.className=""' onmouseover='this.className="blueover"' style="background-color: #ffff80;">
#  <td align="center" class="list_g_line" width="13%">결핵병</td>
#  <td align="center" class="list_g_line" width="13%">
#
#
#                                  준축사
#
#
#
#                              </td>
#  <td align="left" class="list_g_line" width="17%">경상북도 포항시 북구 흥해읍 흥안리</td>
#  <td align="center" class="list_g_line" width="13%">2022-02-10
#  (2022-02-10)</td>
#  <td align="center" class="list_g_line" width="8%">소-한우</td>
#  <td align="center" class="list_g_line1" width="8%">1</td>
#  <td align="left" class="list_g_line" width="16%">경북 동물위생시험소</td>
#  <td align="center" class="list_g_line" width="12%">
#
#
#
#
#
#
#                              </td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" class="page_text">
#  <tr>
#  <td width="15"><a href="#" onclick="fn_page_link(1); return false;"><img alt="firstPageLabel" border="0" src="../../images/dpl/img/page_prev_01.gif" style="vertical-align:middle;"/></a> </td><td width="15"><a href="#" onclick="fn_page_link(1); return false;"><img alt="previousPageLabel" border="0" src="../../images/dpl/img/page_prev.gif" style="vertical-align:middle;"/></a> </td><td style="padding-top:1px;"><strong>1</strong> </td><td><img alt="firstPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(2); return false;">2</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(3); return false;">3</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(4); return false;">4</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(5); return false;">5</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(6); return false;">6</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(7); return false;">7</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(8); return false;">8</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(9); return false;">9</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"> </img></td><td style="padding-top:1px;"><a href="#" onclick="fn_page_link(10); return false;">10</a> </td><td><img alt="currentPageLabel" height="10" src="../../images/dpl/img/page_bar.gif" style="vertical-align:middle;" width="1"/> </td><td width="15"><a href="#" onclick="fn_page_link(11); return false;"><img alt="nextPageLabel" border="0" src="../../images/dpl/img/page_next.gif" style="vertical-align:middle;"/></a> </td><td width="15"><a href="#" onclick="fn_page_link(112); return false;"><img alt="lastPageLabel" border="0" src="../../images/dpl/img/page_next_01.gif" style="vertical-align:middle;"/></a> </td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0">
#  <tr>
#  <td>
#
#                                  전체 : 1112건(1쪽/112쪽)
#
#
#                              </td>
#  </tr>
#  </table>]

# %%
# 페이지에 따라 url이 변하지 않기 때문에 셀레늄 써야함

# %%
driver = webdriver.Chrome()

# %%
url = 'https://home.kahis.go.kr/home/lkntscrinfo/selectLkntsOccrrncList.do'
driver.get(url)

# %%
# 시작날짜 : 달력클릭


# driver.find_element_by_css_selector('#homeLkntscrinfoVO > table:nth-child(5) > tbody > tr > td:nth-child(2) >\
# table:nth-child(1) > tbody > tr > td:nth-child(7) > img').click()

# %%
# 시작날짜 클릭

elem = driver.find_element_by_css_selector('#occrFromDtId')
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/974944847.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrFromDtId')

# %%
# 시작날짜입력칸 클릭
elem.click()

# %%
# 시작날짜입력
elem.send_keys('19900101')

# %%
# 마지막 날짜 클릭
elem = driver.find_element_by_css_selector('#occrToDtId')
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/2421080891.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrToDtId')

# %%
elem.click()

# %%
# 마지막 날짜 입력
elem.send_keys('20220304')

# %%
# 질병명 : '구제역' 고르기

elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
time.sleep(0.5)
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/2829296982.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()

# %%
# 조회 클릭

elem = driver.find_element_by_css_selector('#btnSearch').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3025515801.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#btnSearch').click()

# %%
html = driver.page_source

# %%
df = pd.read_html(html)
df[8]
# Out:
#      0     1                 2                        3       4  5       6  \
# 0  구제역  일호농장  충청북도 충주시 주덕읍 당우리  2019-01-31 (2019-01-31)    소-한우  -  구제역진단과
# 1  구제역   황희선   경기도 안성시 양성면 방축리  2019-01-29 (2019-01-29)    소-한우  -  구제역진단과
# 2  구제역   이한모   경기도 안성시 금광면 오산리  2019-01-28 (2019-01-29)    소-젖소  -  구제역진단과
# 3  구제역  한강농장   경기도 김포시 하성면 시암리  2018-04-01 (2018-04-03)   돼지-일반  -  구제역진단과
# 4  구제역  뒤울농장   경기도 김포시 대곶면 율생리  2018-03-26 (2018-03-27)  돼지-비육돈  -  구제역진단과
# 5  구제역   전용구  충청북도 보은군 탄부면 구암리  2017-02-13 (2017-02-14)    소-한우  -  구제역진단과
# 6  구제역   신원종  충청북도 보은군 마로면 송현리  2017-02-13 (2017-02-14)    소-한우  -  구제역진단과
# 7  구제역   곽팔식  충청북도 보은군 탄부면 구암리  2017-02-13 (2017-02-13)    소-한우  -  구제역진단과
# 8  구제역   서충식  충청북도 보은군 탄부면 상장리  2017-02-12 (2017-02-12)    소-한우  -  구제역진단과
# 9  구제역   구자원  충청북도 보은군 마로면 송현리  2017-02-11 (2017-02-11)    소-한우  -  구제역진단과
#
#             7
# 0  0025-12-19
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
empty = pd.DataFrame()

# %%
df_gu = pd.concat([empty,df[8]])

# %%
# 2페이지

# %%
page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
tr:nth-child(2) > td > table > tbody > tr > td > a')
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/1759985438.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \

# %%
len(page_bar) # 첫페이지, 이전10페이지, 2,3,4,...10 , 다음10페이지, 맨끝페이지 -> 13개 a태그
# Out:
# 13

# %%
# 2페이지 버튼 (3번째)

# %%
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9036/1476318402.py in <module>
# ----> 1 page_bar[3].text
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      75     def text(self) -> str:
#      76         """The text of the element."""
# ---> 77         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      78
#      79     def click(self) -> None:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01279943+2595139]
# 	Ordinal0 [0x0120C9F1+2148849]
# 	Ordinal0 [0x01104528+1066280]
# 	Ordinal0 [0x01106E04+1076740]
# 	Ordinal0 [0x01106CBE+1076414]
# 	Ordinal0 [0x01106F50+1077072]
# 	Ordinal0 [0x0112C920+1231136]
# 	Ordinal0 [0x0114B9EC+1358316]
# 	Ordinal0 [0x01127474+1209460]
# 	Ordinal0 [0x0114BC04+1358852]
# 	Ordinal0 [0x0115BAF2+1424114]
# 	Ordinal0 [0x0114B806+1357830]
# 	Ordinal0 [0x01126086+1204358]
# 	Ordinal0 [0x01126F96+1208214]
# 	GetHandleVerifier [0x0141B232+1658114]
# 	GetHandleVerifier [0x014D312C+2411516]
# 	GetHandleVerifier [0x0130F261+560433]
# 	GetHandleVerifier [0x0130E366+556598]
# 	Ordinal0 [0x0121286B+2173035]
# 	Ordinal0 [0x012175F8+2192888]
# 	Ordinal0 [0x012176E5+2193125]
# 	Ordinal0 [0x012211FC+2232828]
# 	BaseThreadInitThunk [0x7619FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A6E+238]

# %%
for page in page_bar:
    page.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8376/3777629265.py in <module>
#       1 for page in page_bar:
# ----> 2     page.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01279943+2595139]
# 	Ordinal0 [0x0120C9F1+2148849]
# 	Ordinal0 [0x01104528+1066280]
# 	Ordinal0 [0x01106E04+1076740]
# 	Ordinal0 [0x01106CBE+1076414]
# 	Ordinal0 [0x01106F50+1077072]
# 	Ordinal0 [0x0113290C+1255692]
# 	Ordinal0 [0x011279D6+1210838]
# 	Ordinal0 [0x0114B9EC+1358316]
# 	Ordinal0 [0x01127474+1209460]
# 	Ordinal0 [0x0114BC04+1358852]
# 	Ordinal0 [0x0115BAF2+1424114]
# 	Ordinal0 [0x0114B806+1357830]
# 	Ordinal0 [0x01126086+1204358]
# 	Ordinal0 [0x01126F96+1208214]
# 	GetHandleVerifier [0x0141B232+1658114]
# 	GetHandleVerifier [0x014D312C+2411516]
# 	GetHandleVerifier [0x0130F261+560433]
# 	GetHandleVerifier [0x0130E366+556598]
# 	Ordinal0 [0x0121286B+2173035]
# 	Ordinal0 [0x012175F8+2192888]
# 	Ordinal0 [0x012176E5+2193125]
# 	Ordinal0 [0x012211FC+2232828]
# 	BaseThreadInitThunk [0x7619FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A6E+238]

# %%
driver = webdriver.Chrome()

url = 'https://home.kahis.go.kr/home/lkntscrinfo/selectLkntsOccrrncList.do'
driver.get(url)

# 시작날짜 클릭
elem = driver.find_element_by_css_selector('#occrFromDtId')
# 시작날짜입력칸 클릭
elem.click()
# 시작날짜입력
elem.send_keys('19900101')
# 마지막 날짜 클릭
elem = driver.find_element_by_css_selector('#occrToDtId')
elem.click()
# 마지막 날짜 입력
elem.send_keys('20220304')

# 질병명 : '구제역' 고르기

elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
time.sleep(0.5)

# 조회 클릭

elem = driver.find_element_by_css_selector('#btnSearch').click()

# 1페이지는 a태그 따로 출력
html = driver.page_source
df = pd.read_html(html)
df[8]

# 페이지 바 path
page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\
> tr:nth-child(2) > td > table > tbody > tr > td > a')
page_bar[2].click()



url = driver.current_url
driver.get(url)
# 시작날짜 클릭
elem = driver.find_element_by_css_selector('#occrFromDtId')
# 시작날짜입력칸 클릭
elem.click()
# 시작날짜입력
elem.send_keys('19900101')
# 마지막 날짜 클릭
elem = driver.find_element_by_css_selector('#occrToDtId')
elem.click()
# 마지막 날짜 입력
elem.send_keys('20220304')

# 질병명 : '구제역' 고르기

elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
time.sleep(0.5)

# 조회 클릭
elem = driver.find_element_by_css_selector('#btnSearch').click()

# 페이지 바 path
page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\
> tr:nth-child(2) > td > table > tbody > tr > td > a')
page_bar[3].click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrFromDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrToDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#btnSearch').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrFromDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:48: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrToDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:55: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:59: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#btnSearch').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/822420141.py:62: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\

# %%
## 미친 짓 해보기1 

df = pd.DataFrame()
driver = webdriver.Chrome()

url = 'https://home.kahis.go.kr/home/lkntscrinfo/selectLkntsOccrrncList.do'
driver.get(url)

page = 11
for p in range(1,page):
    
    # 시작날짜 클릭
    elem = driver.find_element_by_css_selector('#occrFromDtId')
    # 시작날짜입력칸 클릭
    elem.click()
    # 시작날짜입력
    elem.send_keys('19900101')
    # 마지막 날짜 클릭
    elem = driver.find_element_by_css_selector('#occrToDtId')
    elem.click()
    # 마지막 날짜 입력
    elem.send_keys('20220304')

    # 질병명 : '구제역' 고르기
    elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
    time.sleep(0.5)

    # 조회 클릭

    elem = driver.find_element_by_css_selector('#btnSearch').click()

    # 1페이지는 a태그 따로 출력
    html = driver.page_source
    df1 = pd.read_html(html)
    df = pd.concat([df,df1[8]])

    # 페이지 바 path
    page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\
    > tr:nth-child(2) > td > table > tbody > tr > td > a')
    
    # 페이지클릭
    page_bar[p+1].click()
        
df
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3944618538.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrFromDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3944618538.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrToDtId')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3944618538.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3944618538.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#btnSearch').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9036/3944618538.py:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody\
#       0     1                 2                        3       4  5       6  \
# 0   구제역  일호농장  충청북도 충주시 주덕읍 당우리  2019-01-31 (2019-01-31)    소-한우  -  구제역진단과
# 1   구제역   황희선   경기도 안성시 양성면 방축리  2019-01-29 (2019-01-29)    소-한우  -  구제역진단과
# 2   구제역   이한모   경기도 안성시 금광면 오산리  2019-01-28 (2019-01-29)    소-젖소  -  구제역진단과
# 3   구제역  한강농장   경기도 김포시 하성면 시암리  2018-04-01 (2018-04-03)   돼지-일반  -  구제역진단과
# 4   구제역  뒤울농장   경기도 김포시 대곶면 율생리  2018-03-26 (2018-03-27)  돼지-비육돈  -  구제역진단과
# ..  ...   ...               ...                      ...     ... ..     ...
# 5   구제역   전용구  충청북도 보은군 탄부면 구암리  2017-02-13 (2017-02-14)    소-한우  -  구제역진단과
# 6   구제역   신원종  충청북도 보은군 마로면 송현리  2017-02-13 (2017-02-14)    소-한우  -  구제역진단과
# 7   구제역   곽팔식  충청북도 보은군 탄부면 구암리  2017-02-13 (2017-02-13)    소-한우  -  구제역진단과
# 8   구제역   서충식  충청북도 보은군 탄부면 상장리  2017-02-12 (2017-02-12)    소-한우  -  구제역진단과
# 9   구제역   구자원  충청북도 보은군 마로면 송현리  2017-02-11 (2017-02-11)    소-한우  -  구제역진단과
#
#              7
# 0   0025-12-19
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
#
# [100 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time


driver = webdriver.Chrome()

url = 'https://home.kahis.go.kr/home/lkntscrinfo/selectLkntsOccrrncList.do'
driver.get(url)

# 시작날짜 클릭
elem = driver.find_element_by_css_selector('#occrFromDtId')
# 시작날짜입력칸 클릭
elem.click()
 # 시작날짜입력
elem.send_keys('19900101')
# 마지막 날짜 클릭
elem = driver.find_element_by_css_selector('#occrToDtId')
elem.click()
# 마지막 날짜 입력
elem.send_keys('20220304')

# 질병명 : '구제역' 고르기
elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
time.sleep(0.5)

# 조회 클릭

elem = driver.find_element_by_css_selector('#btnSearch').click()

page = 43
df = pd.DataFrame()
for p in range(1,page+1):
    
    page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
        tr:nth-child(2) > td > table > tbody > tr > td > a')
    for button in page_bar:
        if button.text == str(p):
            button.click()
            break
    html = driver.page_source
    df = pd.concat([df,pd.read_html(html)[8]])
    if p % 10 == 0:
        driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
        tr:nth-child(2) > td > table > tbody > tr > td > a')[11].click()
df
df.to_csv('./data/구제역 발생현황')
# Out:
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrFromDtId')
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#occrToDtId')
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#dissCl > option:nth-child(5)').click()
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector('#btnSearch').click()
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_24992/220185787.py:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_bar = driver.find_elements_by_css_selector('#homeLkntscrinfoVO > table:nth-child(7) > tbody > \
