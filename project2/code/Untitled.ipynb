# %%
import pandas as pd
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('060150','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '003060' # 에이프로젠제약
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '052670' # 제일바이오
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '044960' # 이글벳
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '065170' # 넥스트BT
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '036480' # 대성미생물
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '054670' # 대한뉴팜 가즈..?
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
code = '072020' # 중앙백신 / 가즈아
df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()

df_stock = pd.DataFrame()
for i in range(1,13):
    df_stock_a = fdr.DataReader(code,'2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
plt.figure()
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
