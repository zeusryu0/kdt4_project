# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import datetime

# %%
# 우리나라 기후 불러오기

# %%
df = pd.read_csv('./국내기후(백령도제외).csv', index_col=0)

df['시간'] = pd.to_datetime(df['시간'], format='%Y-%m-%d')

df_k = df[df['시간'] > '2006-12-09']
df_k = df_k[df_k['시간'] < '2021-09-01']
df_k = df_k.reset_index()
df_k.drop('index', axis=1, inplace=True)

df_seoul = df_k[df_k.columns]
df_seoul.columns
df_seoul.drop(['1시간 최다강수량','1시간 최다 일사량', '합계 일조 시간','합계 일사','일 최심신적설','일 최심적설',
               '합계 3시간 신적설',
             '합계 대형증발량','합계 소형증발량'], axis=1, inplace=True)

df_seoul.rename(columns={'시간':'일시', '관측지점':'도시명'}, inplace=True)

west_w = ['서울','전주','광주']
east_w = ['강릉','춘천','청주','대구']
south_w = ['제주']

no_li_w=[]
for i in df_seoul['도시명']:
    if i in west_w:
        no_li_w.append('ko_w')
    elif i in east_w:
        no_li_w.append('ko_e')
    else:
        no_li_w.append('ko_s')
        
df_seoul['군집'] = no_li_w

df_seoul_n = df_seoul.groupby(['군집', '일시']).agg({'평균 기온':'mean','최저 기온':'min','최고 기온':'max',
                                                '일강수량':'mean','최대 순간풍속': 'mean','최대 순간 풍속 풍향':'mean',
                                               '최대 풍속':'mean','최대 풍속 풍향':'mean','평균 풍속':'mean','풍정합':'mean',
                                                '최대 풍향':'mean',
                                               '평균 이슬점온도':'mean','평균 상대습도':'mean','평균 증기압':'mean',
                                               '평균 현지기압':'mean','최고 해면 기압':'max','최저 해면기압':'min',
                                               '평균 해면기압':'mean',
                                               '평균 전운량':'mean','평균 중하층운량':'mean','평균 지면온도':'mean',
                                               '안개 계속 시간':'mean'})
df_seoul_n = df_seoul_n.reset_index()

tdf_k = pd.DataFrame()

gun_k_li = list(df_seoul_n['군집'].unique())

for gun in gun_k_li:
    tmp_k = df_seoul_n[df_seoul_n['군집']==gun].drop(['군집','일시'],axis=1).reset_index(drop=True)
    tmp_k.columns = gun+tmp_k.columns
    tdf_k = pd.concat([tdf_k,tmp_k],axis=1)
df_k_g = tdf_k
df_k_g
# Out:
#       ko_e평균 기온  ko_e최저 기온  ko_e최고 기온  ko_e일강수량  ko_e최대 순간풍속  ko_e최대 순간 풍속 풍향  \
# 0         1.550       -4.1        8.1     0.000        6.550            267.5
# 1         1.675       -6.9        9.2     0.000        4.975            197.5
# 2         4.675       -3.3       13.1     0.000        6.875            235.0
# 3         5.725       -2.0       11.5     0.000        7.500            272.5
# 4         4.050       -2.8        9.1     0.000        6.125            280.0
# ...         ...        ...        ...       ...          ...              ...
# 5374     23.200       19.8       28.7     8.875        6.350            280.0
# 5375     24.575       19.3       31.9     0.075        5.525            192.5
# 5376     23.675       18.6       30.6     6.600        5.725            225.0
# 5377     24.200       19.2       30.6     0.050        4.500            165.0
# 5378     22.275       18.0       29.1    20.175        6.425            190.0
#
#       ko_e최대 풍속  ko_e최대 풍속 풍향  ko_e평균 풍속  ko_e풍정합  ...  ko_w평균 상대습도  \
# 0         3.975         277.5      1.950  1684.50  ...    59.200000
# 1         3.225         220.0      1.425  1231.00  ...    58.566667
# 2         3.975         247.5      1.575  1360.75  ...    65.466667
# 3         3.875         267.5      1.725  1490.25  ...    75.233333
# 4         4.025         277.5      1.475  1274.25  ...    66.333333
# ...         ...           ...        ...      ...  ...          ...
# 5374      3.900         297.5      1.075   945.00  ...    92.233333
# 5375      3.350         192.5      1.450  1249.50  ...    82.166667
# 5376      3.475         220.0      1.400  1191.00  ...    89.300000
# 5377      2.750         217.5      1.250  1054.00  ...    83.700000
# 5378      4.175         187.5      1.600  1383.75  ...    87.266667
#
#       ko_w평균 증기압  ko_w평균 현지기압  ko_w최고 해면 기압  ko_w최저 해면기압  ko_w평균 해면기압  \
# 0       3.866667  1019.333333        1030.0       1025.9  1028.333333
# 1       4.266667  1018.000000        1030.0       1024.1  1026.900000
# 2       6.000000  1016.666667        1027.2       1023.0  1025.466667
# 3       7.533333  1014.533333        1025.6       1020.8  1023.300000
# 4       5.666667  1012.933333        1024.3       1019.4  1021.766667
# ...          ...          ...           ...          ...          ...
# 5374   25.266667  1004.433333        1014.4       1010.3  1012.766667
# 5375   24.300000  1005.633333        1015.5       1012.3  1013.866667
# 5376   26.600000  1005.133333        1015.5       1012.0  1013.366667
# 5377   25.700000  1007.200000        1016.8       1013.7  1015.433333
# 5378   26.533333  1005.733333        1016.4       1010.5  1014.000000
#
#       ko_w평균 전운량  ko_w평균 중하층운량  ko_w평균 지면온도  ko_w안개 계속 시간
# 0       2.366667      0.400000     2.333333      0.000000
# 1       4.666667      1.366667     2.866667      0.000000
# 2       3.266667      1.966667     4.233333      0.000000
# 3       6.933333      4.666667     6.000000      0.000000
# 4       5.700000      3.266667     3.900000      0.000000
# ...          ...           ...          ...           ...
# 5374    8.766667      5.566667    24.333333      0.166667
# 5375    7.200000      4.833333    25.933333      0.000000
# 5376    8.866667      5.433333    26.066667      0.000000
# 5377    8.433333      5.000000    26.100000      0.000000
# 5378    8.733333      4.533333    26.233333      0.000000
#
# [5379 rows x 66 columns]

# %%
# 우리나라 고층기후 가져오기

# %%
df_k_h = pd.read_csv('./preprocessed_고층기후데이터.csv', index_col=0)

df_k_h = df_k_h.reset_index()

df_k_h['일시'] = pd.to_datetime(df_k_h['일시'], format='%Y-%m-%d')
df_k_h = df_k_h[df_k_h['일시'] > '2006-12-09']
df_k_h = df_k_h[df_k_h['일시'] < '2021-09-01']
df_k_h = df_k_h.reset_index()
df_k_h.drop('index', axis=1, inplace=True)

df_k_h
# Out:
#              일시      50hPa_고도  50hPa_기온  50hPa_이슬점    50hPa_풍향   50hPa_풍속  \
# 0    2006-12-10  20405.000000   -57.500 -67.250000  258.750000  53.000000
# 1    2006-12-11  20377.500000   -57.325 -69.075000  260.000000  47.500000
# 2    2006-12-12  20452.500000   -59.150 -73.150000  260.000000  37.250000
# 3    2006-12-13  20492.500000   -58.575 -78.450000  256.666667  38.666667
# 4    2006-12-14  20477.500000   -58.600 -72.350000  258.333333  50.583333
# ...         ...           ...       ...        ...         ...        ...
# 5374 2021-08-27  20969.583333   -57.950 -70.825000   67.500000   9.708333
# 5375 2021-08-28  20968.750000   -58.750 -74.125000  124.375000  11.375000
# 5376 2021-08-29  20958.750000   -58.200 -81.200000  113.125000   6.875000
# 5377 2021-08-30  20970.000000   -57.825 -74.700000  142.500000   9.625000
# 5378 2021-08-31  20990.000000   -57.400 -65.233333  165.833333  14.000000
#
#           70hPa_고도   70hPa_기온  70hPa_이슬점    70hPa_풍향  ...  925hPa_고도  \
# 0     18300.000000 -58.650000 -68.150000  262.500000  ...     839.00
# 1     18280.000000 -60.475000 -71.850000  258.750000  ...     829.25
# 2     18342.500000 -60.550000 -74.300000  260.000000  ...     826.00
# 3     18385.000000 -63.050000 -80.050000  260.000000  ...     811.00
# 4     18390.000000 -63.650000 -76.400000  258.125000  ...     793.25
# ...            ...        ...        ...         ...  ...        ...
# 5374  18878.750000 -65.283333 -73.658333  259.583333  ...     790.50
# 5375  18865.000000 -64.400000 -74.150000  247.500000  ...     803.50
# 5376  18861.250000 -64.600000 -79.850000  260.000000  ...     806.00
# 5377  18868.750000 -63.175000 -73.925000  251.250000  ...     821.50
# 5378  18876.666667 -64.166667 -69.900000  243.797067  ...     803.00
#
#       925hPa_기온  925hPa_이슬점   925hPa_풍향  925hPa_풍속  1000hPa_고도  1000hPa_기온  \
# 0     -4.100000  -20.600000  237.500000  10.000000  220.500000      -0.600
# 1     -1.700000   -9.500000  153.750000  11.000000  205.500000       1.625
# 2      1.750000   -3.300000  266.250000  12.000000  193.250000       5.700
# 3      1.375000   -6.825000  296.250000  11.250000  178.250000       5.800
# 4     -0.775000   -5.525000  288.750000  11.500000  166.000000       3.600
# ...         ...         ...         ...        ...         ...         ...
# 5374  17.600000   15.700000  338.750000  12.750000  117.750000      21.050
# 5375  18.150000   14.775000  302.500000   8.000000  128.500000      21.300
# 5376  18.200000   15.025000  178.750000   8.250000  131.250000      21.850
# 5377  19.750000   13.500000  261.250000   4.500000  144.500000      22.650
# 5378  19.133333   15.233333  148.333333  14.333333  128.333333      20.800
#
#       1000hPa_이슬점  1000hPa_풍향  1000hPa_풍속
# 0      -12.600000      261.25    5.750000
# 1       -8.625000      117.50    5.750000
# 2       -0.050000      157.50    5.000000
# 3       -1.600000      270.00    7.750000
# 4       -5.300000      247.50    4.500000
# ...           ...         ...         ...
# 5374    20.000000      232.50    4.250000
# 5375    18.250000      203.75    5.750000
# 5376    19.800000      163.75    3.750000
# 5377    19.875000      258.75    3.750000
# 5378    18.366667       80.00    8.333333
#
# [5379 rows x 66 columns]

# %%
# 주변국 데이터 불러오기

# %%
df_w = pd.read_csv('./preprocessed_주변국 기상데이터_199601to202108.csv', index_col=0)
# df_w.drop('index', axis=1, inplace=True)

df_w['일시'] = pd.to_datetime(df_w['일시'], format='%Y-%m-%d')
df_w = df_w[df_w['일시'] > '2006-12-09']
df_w = df_w.reset_index()
df_w.drop('index', axis=1, inplace=True)

df_ww = df_w.groupby(['군집', '일시']).agg({ '습도':'mean','풍향':'mean', 
                                            '풍속':'mean', '강수량':'mean','해면기압':'mean', '이슬점 온도':'mean'})
df_ww = df_ww.reset_index()


tdf = pd.DataFrame({'일시':df_ww['일시'].unique()})

gunli = list(df_ww['군집'].unique())

for gun in gunli:
    tmp = df_ww[df_ww['군집']==gun].drop('군집',axis=1)
    tmp.columns = ['일시', f'{gun}습도', f'{gun}풍향', f'{gun}풍속', f'{gun}강수량', f'{gun}해면기압', f'{gun}이슬점 온도']
    tdf = pd.merge(tdf,tmp, how='left',on='일시')
df_w_w = tdf
df_w_w
# Out:
#              일시       n1습도        n1풍향      n1풍속     n1강수량       n1해면기압  \
# 0    2006-12-10  56.928571  230.000000  1.160714  0.000000  1028.351488
# 1    2006-12-11  65.468750  202.500000  2.062500  0.445600  1026.965625
# 2    2006-12-12  72.770833  179.274917  1.005952  0.000000  1024.439583
# 3    2006-12-13  62.916667  248.750000  1.416667  0.000000  1023.255208
# 4    2006-12-14  60.915179  167.500000  0.805804  0.000000  1021.968527
# ...         ...        ...         ...       ...       ...          ...
# 5374 2021-08-27  82.468750  111.250000  0.906250  0.880792  1011.759375
# 5375 2021-08-28  77.921875  115.000000  1.500000  0.000000  1013.007812
# 5376 2021-08-29  83.125000  162.500000  1.031250  1.669771  1013.484375
# 5377 2021-08-30  77.578125  183.750000  0.937500  0.000000  1015.429688
# 5378 2021-08-31  87.421875  123.873900  0.796875  3.130668  1015.906250
#
#        n1이슬점 온도       n2습도   n2풍향      n2풍속  ...      n6풍속     n6강수량  \
# 0     -9.167857  69.571429   27.5  0.607143  ...  2.017857  0.000000
# 1     -4.284375  77.772321   80.0  0.281250  ...  3.010714  0.000000
# 2     -0.572024  73.654762   40.0  0.285714  ...  2.364286  0.000000
# 3     -3.912500  55.000000  102.5  1.750000  ...  2.282143  0.000000
# 4     -6.006473  66.916667  115.0  0.531250  ...  2.389286  0.000000
# ...         ...        ...    ...       ...  ...       ...       ...
# 5374  20.028125  80.593750  350.0  0.937500  ...  2.800000  0.000000
# 5375  19.660938  75.125000  195.0  1.375000  ...  1.996429 -0.594099
# 5376  19.915625  77.875000   42.5  1.218750  ...  1.982143 -0.915458
# 5377  19.173437  73.281250  157.5  1.406250  ...  1.510714 -0.915262
# 5378  18.273438  83.218750  110.0  1.062500  ...  1.621429 -1.465478
#
#            n6해면기압   n6이슬점 온도       n7습도        n7풍향      n7풍속     n7강수량  \
# 0     1025.631786  -7.886429  64.904167  110.000000  2.041667  0.000000
# 1     1021.521429  -3.608929  76.262500  263.333333  2.500000 -0.047822
# 2     1023.791071  -4.638214  79.154167  323.333333  1.791667  0.133333
# 3     1024.350714 -11.458214  71.641667  220.000000  1.666667  1.000000
# 4     1019.422857  -9.447500  68.450000  170.000000  1.875000  0.000000
# ...           ...        ...        ...         ...       ...       ...
# 5374  1009.500000  16.523214  78.830556  240.000000  2.125000 -0.047822
# 5375  1011.968571  16.480000  81.301190  106.666667  1.404762 -0.739609
# 5376  1013.549643  17.045000  87.795833  210.000000  2.083333 -0.702848
# 5377  1015.932500  17.566429  83.704167  220.000000  1.916667 -0.625120
# 5378  1015.305000  17.148929  79.413690  156.666667  2.375000 -0.691787
#
#            n7해면기압   n7이슬점 온도
# 0     1028.425000  -1.791667
# 1     1024.695833   1.304167
# 2     1025.512500   3.220833
# 3     1025.920833   1.837500
# 4     1022.854167  -0.191667
# ...           ...        ...
# 5374  1012.870833  21.366667
# 5375  1012.662500  22.993452
# 5376  1013.058333  23.450000
# 5377  1012.554167  24.179167
# 5378  1011.345833  23.316667
#
# [5379 rows x 43 columns]

# %%
# 황사데이터 불러오기

# %%
df_h = pd.read_csv('./황사.csv', encoding='euckr')

df_h['일시'] = pd.to_datetime(df_h['일시'], format='%Y-%m-%d')
df_h = df_h[df_h['일시'] > '2006-12-09']
df_h = df_h[df_h['일시'] < '2021-09-01']
df_h = df_h.reset_index()
df_h.drop('index', axis=1, inplace=True)

# 서
west_li = ['서울', '강화', '수원', '안면도(감)', '군산', '광주', '광덕산', '백령도', '관악산', '오성산', 
           '전주', '북격렬비도', '천안', '연평도']
# 동
east_li = ['춘천', '추풍령', '안동', '대구', '속초', '북춘천', '대관령', '춘천', '울릉도독도(감)', '영월', '울진', '문경', '영덕']
# 남
south_li = ['고산', '진도군', '구덕산', '울산', '흑산도', '진도(첨찰산)', '진주']

no_li=[]
for i in df_h['지점명']:
    if i in west_li:
        no_li.append('d1')
    elif i in east_li:
        no_li.append('d2')
    else:
        no_li.append('d3')
        
# no_li
df_h['군집'] = no_li

df_h.drop('지점', axis=1, inplace=True)
df_h.rename({'일 미세먼지 농도(㎍/㎥)' : '농도'}, axis=1, inplace=True)

df_h_test = df_h[df_h.columns]

df_h_test = df_h_test.groupby(['군집', '일시']).agg({ '농도':'mean'})
df_h_test = df_h_test.reset_index()


tdf_h = pd.DataFrame({'일시':df_h_test['일시'].unique()})

gun_li_h = list(df_h_test['군집'].unique())

for gun in gun_li_h:
    tmp_h = df_h_test[df_h_test['군집']==gun].drop('군집',axis=1)
    tmp_h.columns = ['일시', f'{gun}농도']
    tdf_h = pd.merge(tdf_h,tmp_h, how='left',on='일시')
df_h_n = tdf_h

import datetime as dt

dat_a = pd.DataFrame({'일시':np.arange(dt.datetime(2006,12,10),dt.datetime(2021,9, 1),dt.timedelta(days=1))})
dat_a['일시'] = dat_a['일시'].apply(lambda x : x.strftime('%Y-%m-%d'))

dat_a['일시'] = dat_a['일시'].astype('datetime64')

df_h_test = pd.merge(dat_a, df_h_n, how='left', on='일시')

df_h_test['d1농도'].interpolate(inplace=True)
df_h_test['d2농도'].interpolate(inplace=True)
df_h_test['d3농도'].interpolate(inplace=True)

df_h_test_a = df_h_test[df_h_test.columns]
df_h_test_w = df_h_test[df_h_test.columns]

df_h_test_a
# Out:
#              일시       d1농도       d2농도       d3농도
# 0    2006-12-10  24.555556  21.000000  23.000000
# 1    2006-12-11  38.111111  20.600000  17.333333
# 2    2006-12-12  63.444444  42.166667  26.666667
# 3    2006-12-13  95.777778  78.500000  43.333333
# 4    2006-12-14  64.666667  70.833333  60.000000
# ...         ...        ...        ...        ...
# 5374 2021-08-27  29.000000  32.200000  22.166667
# 5375 2021-08-28  30.272727  22.900000  16.250000
# 5376 2021-08-29  24.555556  23.200000  19.250000
# 5377 2021-08-30  35.363636  27.200000  19.400000
# 5378 2021-08-31  31.272727  26.222222  21.166667
#
# [5379 rows x 4 columns]

# %%
check_li = [] 
for h in range(len(df_h_test_a)):
    if (df_h_test_a.iloc[h,1] > 80):
        check_li.append(1)
    elif (df_h_test_a.iloc[h,2] > 80):
        check_li.append(1)
    elif (df_h_test_a.iloc[h,3] > 80):
        check_li.append(1)
    else:
        check_li.append(0)

# %%
len(check_li)
# Out:
# 5379

# %%
df_h_test_a['check'] = check_li    
df_h_test_a['target'] = df_h_test_a.check.shift(-3)


df_h_test_a['target'].fillna(0, inplace=True)
df_h_test_a['target'] = df_h_test_a['target'].astype(int)

df_h_test_f = df_h_test_a
df_h_test_f.drop(['d1농도','d2농도','d3농도'], axis=1, inplace=True)
df_h_test_f
# Out:
#              일시  check  target
# 0    2006-12-10      0       1
# 1    2006-12-11      0       0
# 2    2006-12-12      0       1
# 3    2006-12-13      1       0
# 4    2006-12-14      0       0
# ...         ...    ...     ...
# 5374 2021-08-27      0       0
# 5375 2021-08-28      0       0
# 5376 2021-08-29      0       0
# 5377 2021-08-30      0       0
# 5378 2021-08-31      0       0
#
# [5379 rows x 3 columns]

# %%
df_h_test_w = df_h_test[['일시','d1농도']]

df_h_test_w['check'] = df_h_test_w['d1농도'].apply(lambda x: 1 if x > 80 else 0)
df_h_test_w

df_h_test_w['target'] = df_h_test_w.check.shift(-2)
df_h_test_w['target'].fillna(0, inplace=True)
df_h_test_w['target'] = df_h_test_w['target'].astype(int)

df_h_test_w_a = df_h_test_w.drop('d1농도', axis=1)
df_h_test_w_a
# Out:
#              일시  check  target
# 0    2006-12-10      0       0
# 1    2006-12-11      0       1
# 2    2006-12-12      0       0
# 3    2006-12-13      1       1
# 4    2006-12-14      0       0
# ...         ...    ...     ...
# 5374 2021-08-27      0       0
# 5375 2021-08-28      0       0
# 5376 2021-08-29      0       0
# 5377 2021-08-30      0       0
# 5378 2021-08-31      0       0
#
# [5379 rows x 3 columns]

# %%
#  df_k_g - 한국
# df_k_h - 고층
# df_w_w - 세계기후
# df_h_test - 황사

# %%
# merge

# %%
# 4 우리나라+고층+주변국+황사(정답값 빼기?)
df_mm = pd.concat([df_w_w,df_k_g ], axis=1)
df_mm_mm = pd.merge(df_mm,df_h_test_f, how='left', on='일시')

df_a = df_mm_mm[df_mm_mm['일시'] < '2019-01-01']
df_b = df_mm_mm[df_mm_mm['일시'] > '2019-12-31']

# %%
# 5 우리나라+고층+주변국+황사서쪽(정답값 빼기?)
df_mm = pd.concat([df_w_w,df_k_g ], axis=1)
df_mm_mm = pd.merge(df_mm,df_h_test_w_a, how='left', on='일시')

df_a = df_mm_mm[df_mm_mm['일시'] < '2019-01-01']
df_b = df_mm_mm[df_mm_mm['일시'] > '2019-12-31']

# %%
df_ml_m = pd.concat([df_a,df_b])

# %%
# 머신러닝

# %%
y = df_ml_m['target']
x = df_ml_m.drop(['일시','check','target'], axis=1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier

# %%
from sklearn.metrics import classification_report, roc_auc_score

# %%
lr = LogisticRegression()
svc = SVC(probability=True)
rfc = RandomForestClassifier()
xg = XGBClassifier()
knn = KNeighborsClassifier()
lgbm = LGBMClassifier()

models = [lr, svc, rfc, xg, knn, lgbm]

# %%
for m in models:
    m.fit(x_train, y_train)
    pred = m.predict(x_test)
    preb = m.predict_proba(x_test)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.7822735024886012
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.7068845497894259
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.7965438028610212
# ====================================================================================================
# [15:31:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.33      0.03      0.06        61
#
#     accuracy                           0.94      1003
#    macro avg       0.64      0.51      0.51      1003
# weighted avg       0.90      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8277470328216908
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       942
#            1       0.29      0.03      0.06        61
#
#     accuracy                           0.94      1003
#    macro avg       0.61      0.51      0.51      1003
# weighted avg       0.90      0.94      0.91      1003
#
# --------------------------------------------------
# 0.5092147854234103
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.50      0.02      0.03        61
#
#     accuracy                           0.94      1003
#    macro avg       0.72      0.51      0.50      1003
# weighted avg       0.91      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8044968848978455
# ====================================================================================================

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
kfold = KFold()
for m in models:
    score = cross_val_score(m, x_train, y_train, cv=kfold)
    
    print(score)
    print(np.mean(score))
    print(np.std(score))
    print('='*100)
# Out:
# [0.94894147 0.93765586 0.94264339 0.94887781 0.94763092]
# 0.945149889907858
# 0.004401635313264614
# ====================================================================================================
# [0.94894147 0.93640898 0.94264339 0.95012469 0.94763092]
# 0.945149889907858
# 0.00505897818033148
# ====================================================================================================
# [0.94894147 0.93640898 0.94264339 0.95012469 0.94763092]
# 0.945149889907858
# 0.00505897818033148
# ====================================================================================================
# [15:31:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:31:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:31:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:31:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:31:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.94645081 0.93516209 0.94389027 0.94763092 0.94513716]
# 0.9436542516684627
# 0.004427326328185179
# ====================================================================================================
# [0.94645081 0.93142145 0.94389027 0.95012469 0.94763092]
# 0.9439036282270663
# 0.0065557224827936566
# ====================================================================================================
# [0.94894147 0.93640898 0.94389027 0.95137157 0.94638404]
# 0.9453992664664614
# 0.005143690412223482
# ====================================================================================================

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# ko_s평균 증기압         0.050253
# ko_w평균 현지기압        0.038362
# ko_s평균 해면기압        0.028099
# ko_s평균 기온          0.025065
# ko_w평균 증기압         0.021233
# ko_w최저 기온          0.021116
# ko_e안개 계속 시간       0.018010
# n1이슬점 온도           0.017311
# n4습도               0.015897
# ko_e최저 기온          0.015615
# n4이슬점 온도           0.015362
# n3풍향               0.013523
# n5이슬점 온도           0.013439
# ko_s최대 풍속 풍향       0.013346
# n6이슬점 온도           0.013287
# ko_w평균 풍속          0.013255
# ko_s최대 풍속          0.013220
# n7이슬점 온도           0.012954
# ko_w안개 계속 시간       0.012691
# ko_w최저 해면기압        0.012394
# ko_e평균 전운량         0.012359
# n7해면기압             0.012109
# n6해면기압             0.011820
# ko_e최대 순간풍속        0.011621
# ko_s최고 해면 기압       0.011318
# ko_w최대 풍속 풍향       0.011312
# ko_e평균 중하층운량       0.011057
# ko_w최대 순간풍속        0.011053
# n6강수량              0.010883
# ko_s평균 중하층운량       0.010751
# ko_s최고 기온          0.010739
# n7풍속               0.010605
# ko_s최대 순간 풍속 풍향    0.010481
# n6습도               0.010276
# ko_e평균 상대습도        0.010155
# n5해면기압             0.010076
# ko_s평균 지면온도        0.009927
# ko_s평균 전운량         0.009922
# n6풍속               0.009838
# ko_w일강수량           0.009443
# n2강수량              0.009398
# ko_e일강수량           0.009256
# n4풍향               0.009196
# n5풍속               0.009074
# n1습도               0.008915
# n2풍속               0.008572
# n3습도               0.008443
# ko_s일강수량           0.008108
# n7습도               0.008030
# ko_w풍정합            0.007985
# n2해면기압             0.007911
# ko_s평균 이슬점온도       0.007853
# ko_s최대 순간풍속        0.007523
# n1강수량              0.007517
# n1풍속               0.007430
# ko_w최고 기온          0.007389
# ko_w평균 전운량         0.007379
# ko_e평균 기온          0.007364
# n5강수량              0.007276
# n1풍향               0.007253
# dtype: float32

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

std.fit(x_train)
x_train_std = std.transform(x_train)
x_test_std = std.transform(x_test)

# %%
models = [lr, svc, rfc, xg, knn, lgbm]

for m in models:
    m.fit(x_train_std, y_train)
    pred = m.predict(x_test_std)
    preb = m.predict_proba(x_test_std)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.43      0.05      0.09        61
#
#     accuracy                           0.94      1003
#    macro avg       0.69      0.52      0.53      1003
# weighted avg       0.91      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8398071769169191
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.7749469214437367
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.792175698722634
# ====================================================================================================
# [15:31:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.33      0.03      0.06        61
#
#     accuracy                           0.94      1003
#    macro avg       0.64      0.51      0.51      1003
# weighted avg       0.90      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8276252131843654
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       942
#            1       0.33      0.07      0.11        61
#
#     accuracy                           0.94      1003
#    macro avg       0.64      0.53      0.54      1003
# weighted avg       0.91      0.94      0.91      1003
#
# --------------------------------------------------
# 0.6714089311196966
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.20      0.02      0.03        61
#
#     accuracy                           0.94      1003
#    macro avg       0.57      0.51      0.50      1003
# weighted avg       0.89      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8210121471581219
# ====================================================================================================

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# ko_s평균 증기압         0.050253
# ko_w평균 현지기압        0.038362
# ko_s평균 해면기압        0.028099
# ko_s평균 기온          0.025065
# ko_w평균 증기압         0.021233
# ko_w최저 기온          0.021116
# ko_e안개 계속 시간       0.018010
# n1이슬점 온도           0.017311
# n4습도               0.015897
# ko_e최저 기온          0.015615
# n4이슬점 온도           0.015362
# n3풍향               0.013523
# n5이슬점 온도           0.013439
# ko_s최대 풍속 풍향       0.013346
# n6이슬점 온도           0.013287
# ko_w평균 풍속          0.013255
# ko_s최대 풍속          0.013220
# n7이슬점 온도           0.012954
# ko_w안개 계속 시간       0.012691
# ko_w최저 해면기압        0.012394
# ko_e평균 전운량         0.012359
# n7해면기압             0.012109
# n6해면기압             0.011820
# ko_e최대 순간풍속        0.011621
# ko_s최고 해면 기압       0.011318
# ko_w최대 풍속 풍향       0.011312
# ko_e평균 중하층운량       0.011057
# ko_w최대 순간풍속        0.011053
# n6강수량              0.010883
# ko_s평균 중하층운량       0.010751
# ko_s최고 기온          0.010739
# n7풍속               0.010605
# ko_s최대 순간 풍속 풍향    0.010481
# n6습도               0.010276
# ko_e평균 상대습도        0.010155
# n5해면기압             0.010076
# ko_s평균 지면온도        0.009927
# ko_s평균 전운량         0.009922
# n6풍속               0.009838
# ko_w일강수량           0.009443
# n2강수량              0.009398
# ko_e일강수량           0.009256
# n4풍향               0.009196
# n5풍속               0.009074
# n1습도               0.008915
# n2풍속               0.008572
# n3습도               0.008443
# ko_s일강수량           0.008108
# n7습도               0.008030
# ko_w풍정합            0.007985
# n2해면기압             0.007911
# ko_s평균 이슬점온도       0.007853
# ko_s최대 순간풍속        0.007523
# n1강수량              0.007517
# n1풍속               0.007430
# ko_w최고 기온          0.007389
# ko_w평균 전운량         0.007379
# ko_e평균 기온          0.007364
# n5강수량              0.007276
# n1풍향               0.007253
# dtype: float32

# %%
import imblearn
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=100)
x_train_std_sm, y_train_sm = smote.fit_resample(x_train_std, y_train)

y_train_sm.value_counts()
# Out:
# 0    3791
# 1    3791
# Name: target, dtype: int64

# %%
for m in models:
    m.fit(x_train_std_sm, y_train_sm)
    pred = m.predict(x_test_std)
    preb = m.predict_proba(x_test_std)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       942
#            1       0.19      0.72      0.30        61
#
#     accuracy                           0.80      1003
#    macro avg       0.59      0.76      0.59      1003
# weighted avg       0.93      0.80      0.85      1003
#
# --------------------------------------------------
# 0.8397897741115867
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       942
#            1       0.26      0.34      0.29        61
#
#     accuracy                           0.90      1003
#    macro avg       0.61      0.64      0.62      1003
# weighted avg       0.91      0.90      0.91      1003
#
# --------------------------------------------------
# 0.8057498868817654
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       942
#            1       0.19      0.08      0.11        61
#
#     accuracy                           0.92      1003
#    macro avg       0.56      0.53      0.54      1003
# weighted avg       0.90      0.92      0.91      1003
#
# --------------------------------------------------
# 0.8053931293724548
# ====================================================================================================
# [15:32:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       942
#            1       0.23      0.10      0.14        61
#
#     accuracy                           0.93      1003
#    macro avg       0.59      0.54      0.55      1003
# weighted avg       0.90      0.93      0.91      1003
#
# --------------------------------------------------
# 0.8096481152761826
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.98      0.63      0.76       942
#            1       0.12      0.77      0.20        61
#
#     accuracy                           0.64      1003
#    macro avg       0.55      0.70      0.48      1003
# weighted avg       0.92      0.64      0.73      1003
#
# --------------------------------------------------
# 0.7411593748912325
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       942
#            1       0.22      0.10      0.14        61
#
#     accuracy                           0.92      1003
#    macro avg       0.58      0.54      0.55      1003
# weighted avg       0.90      0.92      0.91      1003
#
# --------------------------------------------------
# 0.7830914343392155
# ====================================================================================================

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# n4이슬점 온도           0.102554
# ko_s평균 이슬점온도       0.080910
# ko_s최대 순간 풍속 풍향    0.028674
# ko_s최저 기온          0.027708
# ko_e안개 계속 시간       0.026292
# ko_w일강수량           0.019546
# n4풍향               0.018773
# n7강수량              0.017942
# n6이슬점 온도           0.017294
# ko_e평균 중하층운량       0.017232
# n5이슬점 온도           0.017151
# ko_s최대 풍향          0.016503
# ko_s평균 기온          0.015685
# ko_s일강수량           0.015508
# n1풍향               0.014900
# n1강수량              0.014706
# ko_e최대 풍향          0.013411
# n6해면기압             0.013110
# ko_w안개 계속 시간       0.012712
# n4습도               0.012540
# n3풍향               0.012521
# n7습도               0.012330
# ko_s최대 풍속 풍향       0.012145
# ko_w평균 이슬점온도       0.011810
# n3강수량              0.011586
# n5해면기압             0.011431
# ko_w평균 중하층운량       0.010307
# ko_e평균 풍속          0.009882
# n1습도               0.009828
# n6습도               0.009812
# ko_w최저 해면기압        0.009714
# ko_e일강수량           0.009713
# n7풍향               0.009562
# n1풍속               0.009543
# n2풍향               0.009524
# n4강수량              0.009236
# ko_s풍정합            0.009141
# n2풍속               0.009136
# ko_e평균 상대습도        0.008770
# ko_w최대 풍향          0.008551
# ko_e최대 풍속 풍향       0.008457
# ko_e평균 이슬점온도       0.008039
# ko_s평균 중하층운량       0.007728
# n6풍향               0.007702
# ko_w최대 풍속          0.007337
# ko_w평균 풍속          0.007261
# ko_s평균 전운량         0.006993
# n1이슬점 온도           0.006880
# ko_w최대 풍속 풍향       0.006818
# n7이슬점 온도           0.006766
# ko_s최대 풍속          0.006347
# ko_e최고 해면 기압       0.006120
# n3해면기압             0.006006
# ko_e최저 해면기압        0.005934
# n4풍속               0.005712
# n5풍향               0.005630
# ko_e최고 기온          0.005612
# ko_w평균 현지기압        0.005548
# ko_e최대 순간풍속        0.005494
# ko_s최고 기온          0.005453
# dtype: float32

# %%
from sklearn.model_selection import GridSearchCV
param = { 'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]}

xg_gv = XGBClassifier()
grid = GridSearchCV(xg_gv, param_grid=param, refit=True, verbose=False)
grid.fit(x_train_std_sm, y_train_sm)
# Out:
# [15:33:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:35:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:36:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:37:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
# [16:54:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:54:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:54:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:54:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:54:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:55:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:56:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:57:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_est...jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 1.5, 2, 5], 'max_depth': [3, 4, 5],
#                          'min_child_weight': [1, 5, 10],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=False)

# %%
grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0.5,
#  'max_depth': 5,
#  'min_child_weight': 1,
#  'subsample': 0.6}

# %%
grid.best_score_
# Out:
# 0.9770552037332397

# %%
xg_g = XGBClassifier(colsample_bytree = 0.8,
 gamma = 0.5,
 max_depth = 5,
 min_child_weight = 1,
 subsample = 0.6)

xg_g.fit(x_train_std_sm, y_train_sm)
pred = rfc.predict(x_test_std)
print(classification_report(y_test, pred))
# Out:
# [17:12:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       942
#            1       0.19      0.08      0.11        61
#
#     accuracy                           0.92      1003
#    macro avg       0.56      0.53      0.54      1003
# weighted avg       0.90      0.92      0.91      1003

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# n4이슬점 온도           0.102554
# ko_s평균 이슬점온도       0.080910
# ko_s최대 순간 풍속 풍향    0.028674
# ko_s최저 기온          0.027708
# ko_e안개 계속 시간       0.026292
# ko_w일강수량           0.019546
# n4풍향               0.018773
# n7강수량              0.017942
# n6이슬점 온도           0.017294
# ko_e평균 중하층운량       0.017232
# n5이슬점 온도           0.017151
# ko_s최대 풍향          0.016503
# ko_s평균 기온          0.015685
# ko_s일강수량           0.015508
# n1풍향               0.014900
# n1강수량              0.014706
# ko_e최대 풍향          0.013411
# n6해면기압             0.013110
# ko_w안개 계속 시간       0.012712
# n4습도               0.012540
# n3풍향               0.012521
# n7습도               0.012330
# ko_s최대 풍속 풍향       0.012145
# ko_w평균 이슬점온도       0.011810
# n3강수량              0.011586
# n5해면기압             0.011431
# ko_w평균 중하층운량       0.010307
# ko_e평균 풍속          0.009882
# n1습도               0.009828
# n6습도               0.009812
# ko_w최저 해면기압        0.009714
# ko_e일강수량           0.009713
# n7풍향               0.009562
# n1풍속               0.009543
# n2풍향               0.009524
# n4강수량              0.009236
# ko_s풍정합            0.009141
# n2풍속               0.009136
# ko_e평균 상대습도        0.008770
# ko_w최대 풍향          0.008551
# ko_e최대 풍속 풍향       0.008457
# ko_e평균 이슬점온도       0.008039
# ko_s평균 중하층운량       0.007728
# n6풍향               0.007702
# ko_w최대 풍속          0.007337
# ko_w평균 풍속          0.007261
# ko_s평균 전운량         0.006993
# n1이슬점 온도           0.006880
# ko_w최대 풍속 풍향       0.006818
# n7이슬점 온도           0.006766
# ko_s최대 풍속          0.006347
# ko_e최고 해면 기압       0.006120
# n3해면기압             0.006006
# ko_e최저 해면기압        0.005934
# n4풍속               0.005712
# n5풍향               0.005630
# ko_e최고 기온          0.005612
# ko_w평균 현지기압        0.005548
# ko_e최대 순간풍속        0.005494
# ko_s최고 기온          0.005453
# dtype: float32
