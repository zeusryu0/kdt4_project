# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import datetime

# %%
# 우리나라 기후 불러오기

# %%
df = pd.read_csv('./국내기후(백령도제외).csv', index_col=0)
# df
# Out:
#                시간 관측지점  평균 기온  최저 기온  최고 기온  1시간 최다강수량  일강수량  최대 순간풍속  \
# 0      1990-01-01   서울   -1.7   -4.0    1.8        0.0   0.0      7.3
# 1      1990-01-02   서울   -3.5   -5.7   -0.9        0.0   0.1      8.6
# 2      1990-01-03   서울   -5.0   -7.2   -1.7        0.0   0.0      8.2
# 3      1990-01-04   서울   -3.3   -8.9    2.1        0.0   0.0      6.1
# 4      1990-01-05   서울    0.7   -2.4    2.1        0.0   3.2     12.3
# ...           ...  ...    ...    ...    ...        ...   ...      ...
# 11683  2021-12-27   제주    4.1    0.8    6.5        0.0   0.1     12.8
# 11684  2021-12-28   제주    7.2    5.9    8.4        0.0   0.0      9.1
# 11685  2021-12-29   제주    9.3    6.6   11.5        0.0   0.4     12.8
# 11686  2021-12-30   제주    6.9    5.8    8.4        0.0   0.0     18.1
# 11687  2021-12-31   제주    4.9    3.5    6.4        0.0   0.0     16.4
#
#        최대 순간 풍속 풍향  최대 풍속  ...  합계 일사  일 최심신적설  일 최심적설  합계 3시간 신적설  평균 전운량  \
# 0            270.0    5.0  ...   4.58      0.0     0.0         0.0     3.5
# 1            290.0    4.8  ...   3.44      0.1     0.1         0.1     3.5
# 2            290.0    5.0  ...   7.63      0.0     0.0         0.0     0.0
# 3            290.0    3.0  ...   5.84      0.0     0.0         0.0     0.5
# 4            290.0    7.2  ...   0.36      0.6     0.6         0.6     9.0
# ...            ...    ...  ...    ...      ...     ...         ...     ...
# 11683         20.0    6.8  ...   1.37      0.5     1.2         0.5     8.1
# 11684        360.0    5.3  ...   0.91      0.0     0.0         0.0     8.3
# 11685        340.0    7.9  ...   4.94      0.0     0.0         0.0     8.5
# 11686        340.0   10.1  ...   4.85      0.0     0.0         0.0     8.0
# 11687        340.0    9.5  ...   2.30      0.0     0.0         0.0     8.5
#
#        평균 중하층운량  평균 지면온도  합계 대형증발량  합계 소형증발량  안개 계속 시간
# 0           3.6     -1.5  2.721902       0.9       0.0
# 1           3.8     -2.9  2.721902       0.8       0.0
# 2           0.0     -4.4  2.721902       1.4       0.0
# 3           1.8     -3.6  2.721902       1.0       0.0
# 4           3.6     -0.6  2.721902       1.5       0.0
# ...         ...      ...       ...       ...       ...
# 11683       8.1      3.9  1.000000       1.4       0.0
# 11684       8.0      5.6  0.900000       1.3       0.0
# 11685       7.8      6.9  2.300000       3.3       0.0
# 11686       8.0      5.9  2.300000       3.2       0.0
# 11687       8.5      4.9  1.300000       1.8       0.0
#
# [93504 rows x 33 columns]

# %%
df['시간'] = pd.to_datetime(df['시간'], format='%Y-%m-%d')

# %%
# df[df['시간'].dt.year > 2006]
df_k = df[df['시간'] > '2006-12-09']
df_k = df_k.reset_index()
df_k.drop('index', axis=1, inplace=True)

# %%
df_k
# Out:
#               시간 관측지점  평균 기온  최저 기온  최고 기온  1시간 최다강수량  일강수량  최대 순간풍속  \
# 0     2006-12-10   서울   -0.4   -3.5    3.7        0.0   0.0      6.5
# 1     2006-12-11   서울    1.8   -2.0    6.0        0.0   0.0      5.0
# 2     2006-12-12   서울    5.2    1.2    9.5        0.0   0.0      5.1
# 3     2006-12-13   서울    5.7    3.5    9.8        0.0   0.0      8.6
# 4     2006-12-14   서울    3.3    1.1    6.1        0.0   0.0      6.0
# ...          ...  ...    ...    ...    ...        ...   ...      ...
# 44003 2021-12-27   제주    4.1    0.8    6.5        0.0   0.1     12.8
# 44004 2021-12-28   제주    7.2    5.9    8.4        0.0   0.0      9.1
# 44005 2021-12-29   제주    9.3    6.6   11.5        0.0   0.4     12.8
# 44006 2021-12-30   제주    6.9    5.8    8.4        0.0   0.0     18.1
# 44007 2021-12-31   제주    4.9    3.5    6.4        0.0   0.0     16.4
#
#        최대 순간 풍속 풍향  최대 풍속  ...  합계 일사  일 최심신적설  일 최심적설  합계 3시간 신적설  평균 전운량  \
# 0            290.0    4.1  ...   9.51      0.0     0.0         0.0     2.5
# 1             70.0    3.2  ...   6.24      0.0     0.0         0.0     4.9
# 2            250.0    3.3  ...   5.64      0.0     0.0         0.0     6.1
# 3            320.0    5.0  ...   4.63      0.0     0.0         0.0     5.5
# 4            360.0    3.6  ...   4.76      0.0     0.0         0.0     4.1
# ...            ...    ...  ...    ...      ...     ...         ...     ...
# 44003         20.0    6.8  ...   1.37      0.5     1.2         0.5     8.1
# 44004        360.0    5.3  ...   0.91      0.0     0.0         0.0     8.3
# 44005        340.0    7.9  ...   4.94      0.0     0.0         0.0     8.5
# 44006        340.0   10.1  ...   4.85      0.0     0.0         0.0     8.0
# 44007        340.0    9.5  ...   2.30      0.0     0.0         0.0     8.5
#
#        평균 중하층운량  평균 지면온도  합계 대형증발량  합계 소형증발량  안개 계속 시간
# 0           0.5      1.0  2.721902       1.7       0.0
# 1           1.5      1.2  2.721902       1.0       0.0
# 2           4.3      3.4  2.721902       1.0       0.0
# 3           3.9      4.3  2.721902       0.8       0.0
# 4           2.9      1.8  2.721902       1.0       0.0
# ...         ...      ...       ...       ...       ...
# 44003       8.1      3.9  1.000000       1.4       0.0
# 44004       8.0      5.6  0.900000       1.3       0.0
# 44005       7.8      6.9  2.300000       3.3       0.0
# 44006       8.0      5.9  2.300000       3.2       0.0
# 44007       8.5      4.9  1.300000       1.8       0.0
#
# [44008 rows x 33 columns]

# %%
df_seoul = df_k[df_k['시간'] < '2021-09-01']

# %%
df_seoul.columns
df_seoul.drop(['1시간 최다강수량','1시간 최다 일사량', '합계 일조 시간','합계 일사','일 최심신적설','일 최심적설',
               '합계 3시간 신적설',
             '합계 대형증발량','합계 소형증발량'], axis=1, inplace=True)

# %%
len(df_seoul.columns)
# Out:
# 24

# %%
df_seoul.rename(columns={'시간':'일시', '관측지점':'도시명'}, inplace=True)

# %%
df_seoul['도시명'].unique()
# Out:
# array(['서울', '강릉', '춘천', '청주', '전주', '광주', '대구', '제주'], dtype=object)

# %%
west_w = ['서울','전주','광주']
east_w = ['강릉','춘천','청주','대구']
south_w = ['제주']

# %%
no_li_w=[]
for i in df_seoul['도시명']:
    if i in west_w:
        no_li_w.append('ko_w')
    elif i in east_w:
        no_li_w.append('ko_e')
    else:
        no_li_w.append('ko_s')
        
# no_li_w

# %%
df_seoul['군집'] = no_li_w

# %%
len(df_seoul.columns)
# Out:
# 25

# %%
df_seoul_n = df_seoul.groupby(['군집', '일시']).agg({'평균 기온':'mean','최저 기온':'min','최고 기온':'max',
                                                '일강수량':'mean','최대 순간풍속': 'mean','최대 순간 풍속 풍향':'mean',
                                               '최대 풍속':'mean','최대 풍속 풍향':'mean','평균 풍속':'mean','풍정합':'mean',
                                                '최대 풍향':'mean',
                                               '평균 이슬점온도':'mean','평균 상대습도':'mean','평균 증기압':'mean',
                                               '평균 현지기압':'mean','최고 해면 기압':'max','최저 해면기압':'min',
                                               '평균 해면기압':'mean',
                                               '평균 전운량':'mean','평균 중하층운량':'mean','평균 지면온도':'mean',
                                               '안개 계속 시간':'mean'})
df_seoul_n = df_seoul_n.reset_index()

# %%
df_seoul_n
# Out:
#          군집         일시      평균 기온  최저 기온  최고 기온       일강수량   최대 순간풍속  \
# 0      ko_e 2006-12-10   1.550000   -4.1    8.1   0.000000  6.550000
# 1      ko_e 2006-12-11   1.675000   -6.9    9.2   0.000000  4.975000
# 2      ko_e 2006-12-12   4.675000   -3.3   13.1   0.000000  6.875000
# 3      ko_e 2006-12-13   5.725000   -2.0   11.5   0.000000  7.500000
# 4      ko_e 2006-12-14   4.050000   -2.8    9.1   0.000000  6.125000
# ...     ...        ...        ...    ...    ...        ...       ...
# 16132  ko_w 2021-08-27  22.533333   19.9   28.2  22.933333  8.233333
# 16133  ko_w 2021-08-28  24.100000   19.7   30.4   0.066667  6.000000
# 16134  ko_w 2021-08-29  23.966667   19.4   27.9  20.100000  6.766667
# 16135  ko_w 2021-08-30  24.600000   21.2   29.9   0.633333  5.400000
# 16136  ko_w 2021-08-31  24.400000   18.1   31.5  25.933333  7.766667
#
#        최대 순간 풍속 풍향  최대 풍속    최대 풍속 풍향  ...    평균 상대습도     평균 증기압      평균 현지기압  \
# 0       267.500000  3.975  277.500000  ...  51.875000   3.325000  1020.275000
# 1       197.500000  3.225  220.000000  ...  58.175000   3.900000  1020.225000
# 2       235.000000  3.975  247.500000  ...  61.850000   5.100000  1018.025000
# 3       272.500000  3.875  267.500000  ...  67.275000   6.050000  1015.500000
# 4       280.000000  4.025  277.500000  ...  60.100000   4.750000  1014.225000
# ...            ...    ...         ...  ...        ...        ...          ...
# 16132   256.666667  5.000  263.333333  ...  92.233333  25.266667  1004.433333
# 16133   220.000000  3.200  213.333333  ...  82.166667  24.300000  1005.633333
# 16134   296.666667  4.000  286.666667  ...  89.300000  26.600000  1005.133333
# 16135   293.333333  2.800  280.000000  ...  83.700000  25.700000  1007.200000
# 16136   183.333333  4.400  190.000000  ...  87.266667  26.533333  1005.733333
#
#        최고 해면 기압  최저 해면기압      평균 해면기압    평균 전운량  평균 중하층운량    평균 지면온도  안개 계속 시간
# 0        1029.9   1023.5  1027.150000  2.125000  0.350000   1.850000  0.000000
# 1        1030.7   1023.7  1027.125000  4.375000  0.925000   1.725000  0.000000
# 2        1027.3   1021.3  1024.750000  3.475000  1.725000   3.125000  0.000000
# 3        1025.4   1018.1  1022.225000  6.650000  3.725000   4.100000  1.500000
# 4        1024.0   1017.3  1020.975000  5.075000  2.250000   3.325000  0.000000
# ...         ...      ...          ...       ...       ...        ...       ...
# 16132    1014.4   1010.3  1012.766667  8.766667  5.566667  24.333333  0.166667
# 16133    1015.5   1012.3  1013.866667  7.200000  4.833333  25.933333  0.000000
# 16134    1015.5   1012.0  1013.366667  8.866667  5.433333  26.066667  0.000000
# 16135    1016.8   1013.7  1015.433333  8.433333  5.000000  26.100000  0.000000
# 16136    1016.4   1010.5  1014.000000  8.733333  4.533333  26.233333  0.000000
#
# [16137 rows x 24 columns]

# %%
tdf_k = pd.DataFrame()

gun_k_li = list(df_seoul_n['군집'].unique())

for gun in gun_k_li:
    tmp_k = df_seoul_n[df_seoul_n['군집']==gun].drop(['군집','일시'],axis=1).reset_index(drop=True)
    tmp_k.columns = gun+tmp_k.columns
    tdf_k = pd.concat([tdf_k,tmp_k],axis=1)
df_k_g = tdf_k
df_k_g
# Out:
#       ko_e평균 기온  ko_e최저 기온  ko_e최고 기온  ko_e일강수량  ko_e최대 순간풍속  ko_e최대 순간 풍속 풍향  \
# 0         1.550       -4.1        8.1     0.000        6.550            267.5
# 1         1.675       -6.9        9.2     0.000        4.975            197.5
# 2         4.675       -3.3       13.1     0.000        6.875            235.0
# 3         5.725       -2.0       11.5     0.000        7.500            272.5
# 4         4.050       -2.8        9.1     0.000        6.125            280.0
# ...         ...        ...        ...       ...          ...              ...
# 5374     23.200       19.8       28.7     8.875        6.350            280.0
# 5375     24.575       19.3       31.9     0.075        5.525            192.5
# 5376     23.675       18.6       30.6     6.600        5.725            225.0
# 5377     24.200       19.2       30.6     0.050        4.500            165.0
# 5378     22.275       18.0       29.1    20.175        6.425            190.0
#
#       ko_e최대 풍속  ko_e최대 풍속 풍향  ko_e평균 풍속  ko_e풍정합  ...  ko_w평균 상대습도  \
# 0         3.975         277.5      1.950  1684.50  ...    59.200000
# 1         3.225         220.0      1.425  1231.00  ...    58.566667
# 2         3.975         247.5      1.575  1360.75  ...    65.466667
# 3         3.875         267.5      1.725  1490.25  ...    75.233333
# 4         4.025         277.5      1.475  1274.25  ...    66.333333
# ...         ...           ...        ...      ...  ...          ...
# 5374      3.900         297.5      1.075   945.00  ...    92.233333
# 5375      3.350         192.5      1.450  1249.50  ...    82.166667
# 5376      3.475         220.0      1.400  1191.00  ...    89.300000
# 5377      2.750         217.5      1.250  1054.00  ...    83.700000
# 5378      4.175         187.5      1.600  1383.75  ...    87.266667
#
#       ko_w평균 증기압  ko_w평균 현지기압  ko_w최고 해면 기압  ko_w최저 해면기압  ko_w평균 해면기압  \
# 0       3.866667  1019.333333        1030.0       1025.9  1028.333333
# 1       4.266667  1018.000000        1030.0       1024.1  1026.900000
# 2       6.000000  1016.666667        1027.2       1023.0  1025.466667
# 3       7.533333  1014.533333        1025.6       1020.8  1023.300000
# 4       5.666667  1012.933333        1024.3       1019.4  1021.766667
# ...          ...          ...           ...          ...          ...
# 5374   25.266667  1004.433333        1014.4       1010.3  1012.766667
# 5375   24.300000  1005.633333        1015.5       1012.3  1013.866667
# 5376   26.600000  1005.133333        1015.5       1012.0  1013.366667
# 5377   25.700000  1007.200000        1016.8       1013.7  1015.433333
# 5378   26.533333  1005.733333        1016.4       1010.5  1014.000000
#
#       ko_w평균 전운량  ko_w평균 중하층운량  ko_w평균 지면온도  ko_w안개 계속 시간
# 0       2.366667      0.400000     2.333333      0.000000
# 1       4.666667      1.366667     2.866667      0.000000
# 2       3.266667      1.966667     4.233333      0.000000
# 3       6.933333      4.666667     6.000000      0.000000
# 4       5.700000      3.266667     3.900000      0.000000
# ...          ...           ...          ...           ...
# 5374    8.766667      5.566667    24.333333      0.166667
# 5375    7.200000      4.833333    25.933333      0.000000
# 5376    8.866667      5.433333    26.066667      0.000000
# 5377    8.433333      5.000000    26.100000      0.000000
# 5378    8.733333      4.533333    26.233333      0.000000
#
# [5379 rows x 66 columns]

# %%
# tdf_k = pd.DataFrame({'일시':df_seoul_n['일시'].unique()})

# gun_k_li = list(df_seoul_n['군집'].unique())

# for gun in gun_k_li:
#     tmp_k = df_seoul_n[df_seoul_n['군집']==gun].drop('군집',axis=1)
#     tmp_k.columns = ['일시', f'{gun}평균 기온', f'{gun}최저 기온', f'{gun}최고 기온', f'{gun}1시간 최다강수량', f'{gun}일강수량', 
#                      f'{gun}최대 순간풍속',f'{gun}최대 순간 풍속 풍향',f'{gun}최대 풍속',f'{gun}최대 풍속 풍향'
#                      f'{gun}평균 풍속',
#                      f'{gun}풍정합',f'{gun}최대 풍향',f'{gun}평균 이슬점온도',f'{gun}평균 상대습도',f'{gun}평균 증기압',
#                      f'{gun}평균 현지기압',f'{gun}최고 해면 기압',f'{gun}최저 해면기압',f'{gun}평균 해면기압',f'{gun}합계 일조 시간',
#                      f'{gun}1시간 최다 일사량',f'{gun}합계 일사',f'{gun}일 최심신적설',f'{gun}일 최심적설',f'{gun}합계 3시간 신적설',
#                      f'{gun}평균 전운량',f'{gun}평균 중하층운량',f'{gun}평균 지면온도',f'{gun}합계 대형증발량',f'{gun}합계 소형증발량',
#                      f'{gun}안개 계속 시간']
#     tdf_k = pd.merge(tdf_k,tmp_k, how='left',on='일시')
# df_k_g = tdf_k
# df_k_g

# %%
df_seoul_n.columns
# Out:
# Index(['군집', '일시', '평균 기온', '최저 기온', '최고 기온', '일강수량', '최대 순간풍속', '최대 순간 풍속 풍향',
#        '최대 풍속', '최대 풍속 풍향', '평균 풍속', '풍정합', '최대 풍향', '평균 이슬점온도', '평균 상대습도',
#        '평균 증기압', '평균 현지기압', '최고 해면 기압', '최저 해면기압', '평균 해면기압', '평균 전운량',
#        '평균 중하층운량', '평균 지면온도', '안개 계속 시간'],
#       dtype='object')

# %%
# 우리나라 고층기후 가져오기

# %%
df_k_h = pd.read_csv('./preprocessed_고층기후데이터.csv', index_col=0)
# df_k_h

# %%
df_k_h = df_k_h.reset_index()

# %%
df_k_h.columns
# Out:
# Index(['일시', '50hPa_고도', '50hPa_기온', '50hPa_이슬점', '50hPa_풍향', '50hPa_풍속',
#        '70hPa_고도', '70hPa_기온', '70hPa_이슬점', '70hPa_풍향', '70hPa_풍속',
#        '100hPa_고도', '100hPa_기온', '100hPa_이슬점', '100hPa_풍향', '100hPa_풍속',
#        '150hPa_고도', '150hPa_기온', '150hPa_이슬점', '150hPa_풍향', '150hPa_풍속',
#        '200hPa_고도', '200hPa_기온', '200hPa_이슬점', '200hPa_풍향', '200hPa_풍속',
#        '250hPa_고도', '250hPa_기온', '250hPa_이슬점', '250hPa_풍향', '250hPa_풍속',
#        '300hPa_고도', '300hPa_기온', '300hPa_이슬점', '300hPa_풍향', '300hPa_풍속',
#        '400hPa_고도', '400hPa_기온', '400hPa_이슬점', '400hPa_풍향', '400hPa_풍속',
#        '500hPa_고도', '500hPa_기온', '500hPa_이슬점', '500hPa_풍향', '500hPa_풍속',
#        '700hPa_고도', '700hPa_기온', '700hPa_이슬점', '700hPa_풍향', '700hPa_풍속',
#        '850hPa_고도', '850hPa_기온', '850hPa_이슬점', '850hPa_풍향', '850hPa_풍속',
#        '925hPa_고도', '925hPa_기온', '925hPa_이슬점', '925hPa_풍향', '925hPa_풍속',
#        '1000hPa_고도', '1000hPa_기온', '1000hPa_이슬점', '1000hPa_풍향', '1000hPa_풍속'],
#       dtype='object')

# %%
df_k_h['일시'] = pd.to_datetime(df_k_h['일시'], format='%Y-%m-%d')

# %%
df_k_h = df_k_h[df_k_h['일시'] > '2006-12-09']
df_k_h = df_k_h[df_k_h['일시'] < '2021-09-01']
df_k_h = df_k_h.reset_index()
df_k_h.drop('index', axis=1, inplace=True)

# %%
df_k_h
# Out:
#              일시      50hPa_고도  50hPa_기온  50hPa_이슬점    50hPa_풍향   50hPa_풍속  \
# 0    2006-12-10  20405.000000   -57.500 -67.250000  258.750000  53.000000
# 1    2006-12-11  20377.500000   -57.325 -69.075000  260.000000  47.500000
# 2    2006-12-12  20452.500000   -59.150 -73.150000  260.000000  37.250000
# 3    2006-12-13  20492.500000   -58.575 -78.450000  256.666667  38.666667
# 4    2006-12-14  20477.500000   -58.600 -72.350000  258.333333  50.583333
# ...         ...           ...       ...        ...         ...        ...
# 5374 2021-08-27  20969.583333   -57.950 -70.825000   67.500000   9.708333
# 5375 2021-08-28  20968.750000   -58.750 -74.125000  124.375000  11.375000
# 5376 2021-08-29  20958.750000   -58.200 -81.200000  113.125000   6.875000
# 5377 2021-08-30  20970.000000   -57.825 -74.700000  142.500000   9.625000
# 5378 2021-08-31  20990.000000   -57.400 -65.233333  165.833333  14.000000
#
#           70hPa_고도   70hPa_기온  70hPa_이슬점    70hPa_풍향  ...  925hPa_고도  \
# 0     18300.000000 -58.650000 -68.150000  262.500000  ...     839.00
# 1     18280.000000 -60.475000 -71.850000  258.750000  ...     829.25
# 2     18342.500000 -60.550000 -74.300000  260.000000  ...     826.00
# 3     18385.000000 -63.050000 -80.050000  260.000000  ...     811.00
# 4     18390.000000 -63.650000 -76.400000  258.125000  ...     793.25
# ...            ...        ...        ...         ...  ...        ...
# 5374  18878.750000 -65.283333 -73.658333  259.583333  ...     790.50
# 5375  18865.000000 -64.400000 -74.150000  247.500000  ...     803.50
# 5376  18861.250000 -64.600000 -79.850000  260.000000  ...     806.00
# 5377  18868.750000 -63.175000 -73.925000  251.250000  ...     821.50
# 5378  18876.666667 -64.166667 -69.900000  243.797067  ...     803.00
#
#       925hPa_기온  925hPa_이슬점   925hPa_풍향  925hPa_풍속  1000hPa_고도  1000hPa_기온  \
# 0     -4.100000  -20.600000  237.500000  10.000000  220.500000      -0.600
# 1     -1.700000   -9.500000  153.750000  11.000000  205.500000       1.625
# 2      1.750000   -3.300000  266.250000  12.000000  193.250000       5.700
# 3      1.375000   -6.825000  296.250000  11.250000  178.250000       5.800
# 4     -0.775000   -5.525000  288.750000  11.500000  166.000000       3.600
# ...         ...         ...         ...        ...         ...         ...
# 5374  17.600000   15.700000  338.750000  12.750000  117.750000      21.050
# 5375  18.150000   14.775000  302.500000   8.000000  128.500000      21.300
# 5376  18.200000   15.025000  178.750000   8.250000  131.250000      21.850
# 5377  19.750000   13.500000  261.250000   4.500000  144.500000      22.650
# 5378  19.133333   15.233333  148.333333  14.333333  128.333333      20.800
#
#       1000hPa_이슬점  1000hPa_풍향  1000hPa_풍속
# 0      -12.600000      261.25    5.750000
# 1       -8.625000      117.50    5.750000
# 2       -0.050000      157.50    5.000000
# 3       -1.600000      270.00    7.750000
# 4       -5.300000      247.50    4.500000
# ...           ...         ...         ...
# 5374    20.000000      232.50    4.250000
# 5375    18.250000      203.75    5.750000
# 5376    19.800000      163.75    3.750000
# 5377    19.875000      258.75    3.750000
# 5378    18.366667       80.00    8.333333
#
# [5379 rows x 66 columns]

# %%
# 주변국 데이터 불러오기

# %%
df_w = pd.read_csv('./preprocessed_주변국 기상데이터_199601to202108.csv', index_col=0)
# df_w.drop('index', axis=1, inplace=True)

df_w['일시'] = pd.to_datetime(df_w['일시'], format='%Y-%m-%d')
df_w = df_w[df_w['일시'] > '2006-12-09']
df_w = df_w.reset_index()
df_w.drop('index', axis=1, inplace=True)

df_w
# Out:
#          도시명         일시       평균기온  최고기온  최저기온         습도     풍향        풍속  \
# 0         청진 2006-12-10  -2.371429   0.4  -5.0  54.857143   40.0  1.428571
# 1         청진 2006-12-11  -2.062500   2.1  -4.9  84.250000  290.0  0.375000
# 2         청진 2006-12-12   0.600000   5.9  -2.3  79.000000   90.0  0.142857
# 3         청진 2006-12-13   2.466667   4.7  -0.8  48.666667  320.0  3.333333
# 4         청진 2006-12-14   0.362500   3.1  -2.7  59.250000  320.0  0.875000
# ...      ...        ...        ...   ...   ...        ...    ...       ...
# 155986  후쿠오카 2021-08-27  29.175000  32.8  25.6  70.495833   30.0  5.125000
# 155987  후쿠오카 2021-08-28  28.641667  32.3  25.1  72.362500   40.0  4.958333
# 155988  후쿠오카 2021-08-29  28.908333  32.4  25.5  72.687500  290.0  5.041667
# 155989  후쿠오카 2021-08-30  28.904167  32.5  25.8  75.795833  310.0  4.541667
# 155990  후쿠오카 2021-08-31  29.100000  32.3  26.8  73.162500  290.0  4.875000
#
#              강수량         해면기압     이슬점 온도  군집
# 0       0.000000  1027.042857 -10.800000  n2
# 1       0.000000  1027.775000  -4.375000  n2
# 2       0.000000  1022.028571  -2.828571  n2
# 3       0.000000  1019.133333  -9.900000  n2
# 4       2.123669  1021.525000  -8.062500  n2
# ...          ...          ...        ...  ..
# 155986  0.000000  1014.391667  23.162500  n5
# 155987  0.000000  1014.325000  23.000000  n5
# 155988  0.000000  1014.754167  23.375000  n5
# 155989  0.000000  1015.587500  24.112500  n5
# 155990  0.000000  1013.795833  23.754167  n5
#
# [155991 rows x 12 columns]

# %%
df_ww = df_w.groupby(['군집', '일시']).agg({ '습도':'mean','풍향':'mean', 
                                            '풍속':'mean', '강수량':'mean','해면기압':'mean', '이슬점 온도':'mean'})
df_ww = df_ww.reset_index()
# df_ww

# %%
tdf = pd.DataFrame({'일시':df_ww['일시'].unique()})

# %%
gunli = list(df_ww['군집'].unique())

for gun in gunli:
    tmp = df_ww[df_ww['군집']==gun].drop('군집',axis=1)
    tmp.columns = ['일시', f'{gun}습도', f'{gun}풍향', f'{gun}풍속', f'{gun}강수량', f'{gun}해면기압', f'{gun}이슬점 온도']
    tdf = pd.merge(tdf,tmp, how='left',on='일시')
df_w_w = tdf
df_w_w
# Out:
#              일시       n1습도        n1풍향      n1풍속     n1강수량       n1해면기압  \
# 0    2006-12-10  56.928571  230.000000  1.160714  0.000000  1028.351488
# 1    2006-12-11  65.468750  202.500000  2.062500  0.445600  1026.965625
# 2    2006-12-12  72.770833  179.274917  1.005952  0.000000  1024.439583
# 3    2006-12-13  62.916667  248.750000  1.416667  0.000000  1023.255208
# 4    2006-12-14  60.915179  167.500000  0.805804  0.000000  1021.968527
# ...         ...        ...         ...       ...       ...          ...
# 5374 2021-08-27  82.468750  111.250000  0.906250  0.880792  1011.759375
# 5375 2021-08-28  77.921875  115.000000  1.500000  0.000000  1013.007812
# 5376 2021-08-29  83.125000  162.500000  1.031250  1.669771  1013.484375
# 5377 2021-08-30  77.578125  183.750000  0.937500  0.000000  1015.429688
# 5378 2021-08-31  87.421875  123.873900  0.796875  3.130668  1015.906250
#
#        n1이슬점 온도       n2습도   n2풍향      n2풍속  ...      n6풍속     n6강수량  \
# 0     -9.167857  69.571429   27.5  0.607143  ...  2.017857  0.000000
# 1     -4.284375  77.772321   80.0  0.281250  ...  3.010714  0.000000
# 2     -0.572024  73.654762   40.0  0.285714  ...  2.364286  0.000000
# 3     -3.912500  55.000000  102.5  1.750000  ...  2.282143  0.000000
# 4     -6.006473  66.916667  115.0  0.531250  ...  2.389286  0.000000
# ...         ...        ...    ...       ...  ...       ...       ...
# 5374  20.028125  80.593750  350.0  0.937500  ...  2.800000  0.000000
# 5375  19.660938  75.125000  195.0  1.375000  ...  1.996429 -0.594099
# 5376  19.915625  77.875000   42.5  1.218750  ...  1.982143 -0.915458
# 5377  19.173437  73.281250  157.5  1.406250  ...  1.510714 -0.915262
# 5378  18.273438  83.218750  110.0  1.062500  ...  1.621429 -1.465478
#
#            n6해면기압   n6이슬점 온도       n7습도        n7풍향      n7풍속     n7강수량  \
# 0     1025.631786  -7.886429  64.904167  110.000000  2.041667  0.000000
# 1     1021.521429  -3.608929  76.262500  263.333333  2.500000 -0.047822
# 2     1023.791071  -4.638214  79.154167  323.333333  1.791667  0.133333
# 3     1024.350714 -11.458214  71.641667  220.000000  1.666667  1.000000
# 4     1019.422857  -9.447500  68.450000  170.000000  1.875000  0.000000
# ...           ...        ...        ...         ...       ...       ...
# 5374  1009.500000  16.523214  78.830556  240.000000  2.125000 -0.047822
# 5375  1011.968571  16.480000  81.301190  106.666667  1.404762 -0.739609
# 5376  1013.549643  17.045000  87.795833  210.000000  2.083333 -0.702848
# 5377  1015.932500  17.566429  83.704167  220.000000  1.916667 -0.625120
# 5378  1015.305000  17.148929  79.413690  156.666667  2.375000 -0.691787
#
#            n7해면기압   n7이슬점 온도
# 0     1028.425000  -1.791667
# 1     1024.695833   1.304167
# 2     1025.512500   3.220833
# 3     1025.920833   1.837500
# 4     1022.854167  -0.191667
# ...           ...        ...
# 5374  1012.870833  21.366667
# 5375  1012.662500  22.993452
# 5376  1013.058333  23.450000
# 5377  1012.554167  24.179167
# 5378  1011.345833  23.316667
#
# [5379 rows x 43 columns]

# %%
# 황사데이터 불러오기

# %%
df_h = pd.read_csv('./황사.csv', encoding='euckr')
# df_w.drop('index', axis=1, inplace=True)
df_h
# Out:
#          지점  지점명          일시  일 미세먼지 농도(㎍/㎥)
# 0        90   속초  2006-12-10              22
# 1        90   속초  2006-12-11              26
# 2        90   속초  2006-12-12              47
# 3        90   속초  2006-12-13              84
# 4        90   속초  2006-12-14              50
# ...     ...  ...         ...             ...
# 151309  501  연평도  2022-02-27              34
# 151310  501  연평도  2022-02-28              28
# 151311  501  연평도  2022-03-01              26
# 151312  501  연평도  2022-03-02              23
# 151313  501  연평도  2022-03-03              37
#
# [151314 rows x 4 columns]

# %%
df_h['지점명'].unique()
# Out:
# array(['속초', '북춘천', '광덕산', '대관령', '춘천', '백령도', '서울', '울릉도독도(감)', '관악산',
#        '수원', '영월', '울진', '안면도(감)', '추풍령', '안동', '군산', '대구', '오성산', '전주',
#        '울산', '광주', '구덕산', '흑산도', '진도(첨찰산)', '고산', '진주', '강화', '북격렬비도',
#        '천안', '진도군', '문경', '영덕', '연평도'], dtype=object)

# %%
df_h['일시'] = pd.to_datetime(df_h['일시'], format='%Y-%m-%d')
df_h = df_h[df_h['일시'] > '2006-12-09']
df_h = df_h[df_h['일시'] < '2021-09-01']
df_h = df_h.reset_index()
df_h.drop('index', axis=1, inplace=True)

# %%
df_h['일시'].sort_values
# Out:
# <bound method Series.sort_values of 0        2006-12-10
# 1        2006-12-11
# 2        2006-12-12
# 3        2006-12-13
# 4        2006-12-14
#             ...
# 133473   2021-08-27
# 133474   2021-08-28
# 133475   2021-08-29
# 133476   2021-08-30
# 133477   2021-08-31
# Name: 일시, Length: 133478, dtype: datetime64[ns]>

# %%
df_h
# Out:
#          지점  지점명         일시  일 미세먼지 농도(㎍/㎥)
# 0        90   속초 2006-12-10              22
# 1        90   속초 2006-12-11              26
# 2        90   속초 2006-12-12              47
# 3        90   속초 2006-12-13              84
# 4        90   속초 2006-12-14              50
# ...     ...  ...        ...             ...
# 133473  501  연평도 2021-08-27              20
# 133474  501  연평도 2021-08-28              26
# 133475  501  연평도 2021-08-29              16
# 133476  501  연평도 2021-08-30              34
# 133477  501  연평도 2021-08-31              19
#
# [133478 rows x 4 columns]

# %%
# 서
west_li = ['서울', '강화', '수원', '안면도(감)', '군산', '광주', '광덕산', '백령도', '관악산', '오성산', 
           '전주', '북격렬비도', '천안', '연평도']

# %%
# 동
east_li = ['춘천', '추풍령', '안동', '대구', '속초', '북춘천', '대관령', '춘천', '울릉도독도(감)', '영월', '울진', '문경', '영덕']

# %%
# 남
south_li = ['고산', '진도군', '구덕산', '울산', '흑산도', '진도(첨찰산)', '진주']

# %%
df_h['지점명'].tail(50)
# Out:
# 133428    연평도
# 133429    연평도
# 133430    연평도
# 133431    연평도
# 133432    연평도
# 133433    연평도
# 133434    연평도
# 133435    연평도
# 133436    연평도
# 133437    연평도
# 133438    연평도
# 133439    연평도
# 133440    연평도
# 133441    연평도
# 133442    연평도
# 133443    연평도
# 133444    연평도
# 133445    연평도
# 133446    연평도
# 133447    연평도
# 133448    연평도
# 133449    연평도
# 133450    연평도
# 133451    연평도
# 133452    연평도
# 133453    연평도
# 133454    연평도
# 133455    연평도
# 133456    연평도
# 133457    연평도
# 133458    연평도
# 133459    연평도
# 133460    연평도
# 133461    연평도
# 133462    연평도
# 133463    연평도
# 133464    연평도
# 133465    연평도
# 133466    연평도
# 133467    연평도
# 133468    연평도
# 133469    연평도
# 133470    연평도
# 133471    연평도
# 133472    연평도
# 133473    연평도
# 133474    연평도
# 133475    연평도
# 133476    연평도
# 133477    연평도
# Name: 지점명, dtype: object

# %%
no_li=[]
for i in df_h['지점명']:
    if i in west_li:
        no_li.append('d1')
    elif i in east_li:
        no_li.append('d2')
    else:
        no_li.append('d3')
        
# no_li

# %%
df_h['군집'] = no_li

# %%
df_h.isna().sum()
# Out:
# 지점                0
# 지점명               0
# 일시                0
# 일 미세먼지 농도(㎍/㎥)    0
# 군집                0
# dtype: int64

# %%
df_h['군집'].value_counts()
# Out:
# d1    59597
# d2    45849
# d3    28032
# Name: 군집, dtype: int64

# %%
df_h.drop('지점', axis=1, inplace=True)
df_h.rename({'일 미세먼지 농도(㎍/㎥)' : '농도'}, axis=1, inplace=True)

# %%
df_h_test = df_h

# %%
df_h_test = df_h_test.groupby(['군집', '일시']).agg({ '농도':'mean'})
df_h_test = df_h_test.reset_index()

# %%
df_h_test[df_h_test['농도'].isna()]
# Out:
# Empty DataFrame
# Columns: [군집, 일시, 농도]
# Index: []

# %%
df_h_test
# Out:
#        군집         일시         농도
# 0      d1 2006-12-10  24.555556
# 1      d1 2006-12-11  38.111111
# 2      d1 2006-12-12  63.444444
# 3      d1 2006-12-13  95.777778
# 4      d1 2006-12-14  64.666667
# ...    ..        ...        ...
# 16120  d3 2021-08-27  22.166667
# 16121  d3 2021-08-28  16.250000
# 16122  d3 2021-08-29  19.250000
# 16123  d3 2021-08-30  19.400000
# 16124  d3 2021-08-31  21.166667
#
# [16125 rows x 3 columns]

# %%
df_h_test[df_h_test['농도'].isna()]
# Out:
# Empty DataFrame
# Columns: [군집, 일시, 농도]
# Index: []

# %%
tdf_h = pd.DataFrame({'일시':df_h_test['일시'].unique()})

# %%
gun_li_h = list(df_h_test['군집'].unique())

for gun in gun_li_h:
    tmp_h = df_h_test[df_h_test['군집']==gun].drop('군집',axis=1)
    tmp_h.columns = ['일시', f'{gun}농도']
    tdf_h = pd.merge(tdf_h,tmp_h, how='left',on='일시')
df_h_n = tdf_h
df_h_n
# Out:
#              일시       d1농도       d2농도       d3농도
# 0    2006-12-10  24.555556  21.000000  23.000000
# 1    2006-12-11  38.111111  20.600000  17.333333
# 2    2006-12-12  63.444444  42.166667  26.666667
# 3    2006-12-13  95.777778  78.500000  43.333333
# 4    2006-12-14  64.666667  70.833333  60.000000
# ...         ...        ...        ...        ...
# 5372 2021-08-27  29.000000  32.200000  22.166667
# 5373 2021-08-28  30.272727  22.900000  16.250000
# 5374 2021-08-29  24.555556  23.200000  19.250000
# 5375 2021-08-30  35.363636  27.200000  19.400000
# 5376 2021-08-31  31.272727  26.222222  21.166667
#
# [5377 rows x 4 columns]

# %%
import datetime as dt

dat_a = pd.DataFrame({'일시':np.arange(dt.datetime(2006,12,10),dt.datetime(2021,9, 1),dt.timedelta(days=1))})
dat_a['일시'] = dat_a['일시'].apply(lambda x : x.strftime('%Y-%m-%d'))

# %%
dat_a['일시'] = dat_a['일시'].astype('datetime64')

# %%
dat_a
# Out:
#              일시
# 0    2006-12-10
# 1    2006-12-11
# 2    2006-12-12
# 3    2006-12-13
# 4    2006-12-14
# ...         ...
# 5374 2021-08-27
# 5375 2021-08-28
# 5376 2021-08-29
# 5377 2021-08-30
# 5378 2021-08-31
#
# [5379 rows x 1 columns]

# %%
df_h_test = pd.merge(dat_a, df_h_n, how='left', on='일시')

# %%
df_h_test
# Out:
#              일시       d1농도       d2농도       d3농도
# 0    2006-12-10  24.555556  21.000000  23.000000
# 1    2006-12-11  38.111111  20.600000  17.333333
# 2    2006-12-12  63.444444  42.166667  26.666667
# 3    2006-12-13  95.777778  78.500000  43.333333
# 4    2006-12-14  64.666667  70.833333  60.000000
# ...         ...        ...        ...        ...
# 5374 2021-08-27  29.000000  32.200000  22.166667
# 5375 2021-08-28  30.272727  22.900000  16.250000
# 5376 2021-08-29  24.555556  23.200000  19.250000
# 5377 2021-08-30  35.363636  27.200000  19.400000
# 5378 2021-08-31  31.272727  26.222222  21.166667
#
# [5379 rows x 4 columns]

# %%
df_h_test[df_h_test['d1농도'].isna()]
# Out:
#              일시  d1농도  d2농도  d3농도
# 4685 2019-10-08   NaN   NaN   NaN
# 4686 2019-10-09   NaN   NaN   NaN

# %%
df_h_test['d1농도'].interpolate(inplace=True)
df_h_test['d2농도'].interpolate(inplace=True)
df_h_test['d3농도'].interpolate(inplace=True)

# %%
df_h_test.isna().sum()
# Out:
# 일시      0
# d1농도    0
# d2농도    0
# d3농도    0
# dtype: int64

# %%
df_h_test
# Out:
#              일시       d1농도       d2농도       d3농도
# 0    2006-12-10  24.555556  21.000000  23.000000
# 1    2006-12-11  38.111111  20.600000  17.333333
# 2    2006-12-12  63.444444  42.166667  26.666667
# 3    2006-12-13  95.777778  78.500000  43.333333
# 4    2006-12-14  64.666667  70.833333  60.000000
# ...         ...        ...        ...        ...
# 5374 2021-08-27  29.000000  32.200000  22.166667
# 5375 2021-08-28  30.272727  22.900000  16.250000
# 5376 2021-08-29  24.555556  23.200000  19.250000
# 5377 2021-08-30  35.363636  27.200000  19.400000
# 5378 2021-08-31  31.272727  26.222222  21.166667
#
# [5379 rows x 4 columns]

# %%
df_h_test_w = df_h_test[['일시','d1농도']]

# %%
df_h_test_w['check'] = df_h_test_w['d1농도'].apply(lambda x: 1 if x > 80 else 0)
df_h_test_w
# Out:
#              일시       d1농도  check
# 0    2006-12-10  24.555556      0
# 1    2006-12-11  38.111111      0
# 2    2006-12-12  63.444444      0
# 3    2006-12-13  95.777778      1
# 4    2006-12-14  64.666667      0
# ...         ...        ...    ...
# 5374 2021-08-27  29.000000      0
# 5375 2021-08-28  30.272727      0
# 5376 2021-08-29  24.555556      0
# 5377 2021-08-30  35.363636      0
# 5378 2021-08-31  31.272727      0
#
# [5379 rows x 3 columns]

# %%
df_h_test_w['target'] = df_h_test_w.check.shift(-2)

# %%
df_h_test_w
# Out:
#              일시       d1농도  check  target
# 0    2006-12-10  24.555556      0     0.0
# 1    2006-12-11  38.111111      0     1.0
# 2    2006-12-12  63.444444      0     0.0
# 3    2006-12-13  95.777778      1     1.0
# 4    2006-12-14  64.666667      0     0.0
# ...         ...        ...    ...     ...
# 5374 2021-08-27  29.000000      0     0.0
# 5375 2021-08-28  30.272727      0     0.0
# 5376 2021-08-29  24.555556      0     0.0
# 5377 2021-08-30  35.363636      0     NaN
# 5378 2021-08-31  31.272727      0     NaN
#
# [5379 rows x 4 columns]

# %%
df_h_test_w['target'].fillna(0, inplace=True)

# %%
df_h_test_w['target'] = df_h_test_w['target'].astype(int)

# %%
df_h_test_w
# Out:
#              일시       d1농도  check  target
# 0    2006-12-10  24.555556      0       0
# 1    2006-12-11  38.111111      0       1
# 2    2006-12-12  63.444444      0       0
# 3    2006-12-13  95.777778      1       1
# 4    2006-12-14  64.666667      0       0
# ...         ...        ...    ...     ...
# 5374 2021-08-27  29.000000      0       0
# 5375 2021-08-28  30.272727      0       0
# 5376 2021-08-29  24.555556      0       0
# 5377 2021-08-30  35.363636      0       0
# 5378 2021-08-31  31.272727      0       0
#
# [5379 rows x 4 columns]

# %%
#  df_k_g - 한국
# df_k_h - 고층
# df_w_w - 세계기후
# df_h_test - 황사

# %%
# merge

# %%
df_m = pd.concat([df_k_h,df_k_g], axis=1)
# pd.concat([tdf_k,tmp_k],axis=1)

# %%
df_m.isna().sum().sum()
# Out:
# 0

# %%
#1
df_m = pd.merge(df_m,df_w_w, how='left', on='일시')

# %%
# 2
df_mm = pd.concat([df_w_w,df_k_g ], axis=1)

# %%
df_ml
# Out:
#              일시      50hPa_고도  50hPa_기온  50hPa_이슬점    50hPa_풍향   50hPa_풍속  \
# 0    2006-12-10  20405.000000   -57.500 -67.250000  258.750000  53.000000
# 1    2006-12-11  20377.500000   -57.325 -69.075000  260.000000  47.500000
# 2    2006-12-12  20452.500000   -59.150 -73.150000  260.000000  37.250000
# 3    2006-12-13  20492.500000   -58.575 -78.450000  256.666667  38.666667
# 4    2006-12-14  20477.500000   -58.600 -72.350000  258.333333  50.583333
# ...         ...           ...       ...        ...         ...        ...
# 5374 2021-08-27  20969.583333   -57.950 -70.825000   67.500000   9.708333
# 5375 2021-08-28  20968.750000   -58.750 -74.125000  124.375000  11.375000
# 5376 2021-08-29  20958.750000   -58.200 -81.200000  113.125000   6.875000
# 5377 2021-08-30  20970.000000   -57.825 -74.700000  142.500000   9.625000
# 5378 2021-08-31  20990.000000   -57.400 -65.233333  165.833333  14.000000
#
#           70hPa_고도   70hPa_기온  70hPa_이슬점    70hPa_풍향  ...      n6풍속     n6강수량  \
# 0     18300.000000 -58.650000 -68.150000  262.500000  ...  2.017857  0.000000
# 1     18280.000000 -60.475000 -71.850000  258.750000  ...  3.010714  0.000000
# 2     18342.500000 -60.550000 -74.300000  260.000000  ...  2.364286  0.000000
# 3     18385.000000 -63.050000 -80.050000  260.000000  ...  2.282143  0.000000
# 4     18390.000000 -63.650000 -76.400000  258.125000  ...  2.389286  0.000000
# ...            ...        ...        ...         ...  ...       ...       ...
# 5374  18878.750000 -65.283333 -73.658333  259.583333  ...  2.800000  0.000000
# 5375  18865.000000 -64.400000 -74.150000  247.500000  ...  1.996429 -0.594099
# 5376  18861.250000 -64.600000 -79.850000  260.000000  ...  1.982143 -0.915458
# 5377  18868.750000 -63.175000 -73.925000  251.250000  ...  1.510714 -0.915262
# 5378  18876.666667 -64.166667 -69.900000  243.797067  ...  1.621429 -1.465478
#
#            n6해면기압   n6이슬점 온도       n7습도        n7풍향      n7풍속     n7강수량  \
# 0     1025.631786  -7.886429  64.904167  110.000000  2.041667  0.000000
# 1     1021.521429  -3.608929  76.262500  263.333333  2.500000 -0.047822
# 2     1023.791071  -4.638214  79.154167  323.333333  1.791667  0.133333
# 3     1024.350714 -11.458214  71.641667  220.000000  1.666667  1.000000
# 4     1019.422857  -9.447500  68.450000  170.000000  1.875000  0.000000
# ...           ...        ...        ...         ...       ...       ...
# 5374  1009.500000  16.523214  78.830556  240.000000  2.125000 -0.047822
# 5375  1011.968571  16.480000  81.301190  106.666667  1.404762 -0.739609
# 5376  1013.549643  17.045000  87.795833  210.000000  2.083333 -0.702848
# 5377  1015.932500  17.566429  83.704167  220.000000  1.916667 -0.625120
# 5378  1015.305000  17.148929  79.413690  156.666667  2.375000 -0.691787
#
#            n7해면기압   n7이슬점 온도
# 0     1028.425000  -1.791667
# 1     1024.695833   1.304167
# 2     1025.512500   3.220833
# 3     1025.920833   1.837500
# 4     1022.854167  -0.191667
# ...           ...        ...
# 5374  1012.870833  21.366667
# 5375  1012.662500  22.993452
# 5376  1013.058333  23.450000
# 5377  1012.554167  24.179167
# 5378  1011.345833  23.316667
#
# [5379 rows x 174 columns]

# %%
df_ml_m = pd.merge(df_ml,df_h_test_w, how='left', on='일시')

# %%
df_mm_m = pd.merge(df_mm,df_h_test_w, how='left', on='일시')

# %%
df_ml_m.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36888/3206708374.py in <module>
# ----> 1 df_ml_m.columns
#
# NameError: name 'df_ml_m' is not defined

# %%
df_ml_m = df_ml_m[df_ml_m['일시'] < '2020-01-01']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36888/409289545.py in <module>
# ----> 1 df_ml_m = df_ml_m[df_ml_m['일시'] < '2020-01-01']
#
# NameError: name 'df_ml_m' is not defined

# %%
df_ml_m = df_mm_m[df_mm_m['일시'] < '2019-01-01']

# %%
df_mm_m
# Out:
#              일시       n1습도        n1풍향      n1풍속     n1강수량       n1해면기압  \
# 0    2006-12-10  56.928571  230.000000  1.160714  0.000000  1028.351488
# 1    2006-12-11  65.468750  202.500000  2.062500  0.445600  1026.965625
# 2    2006-12-12  72.770833  179.274917  1.005952  0.000000  1024.439583
# 3    2006-12-13  62.916667  248.750000  1.416667  0.000000  1023.255208
# 4    2006-12-14  60.915179  167.500000  0.805804  0.000000  1021.968527
# ...         ...        ...         ...       ...       ...          ...
# 5374 2021-08-27  82.468750  111.250000  0.906250  0.880792  1011.759375
# 5375 2021-08-28  77.921875  115.000000  1.500000  0.000000  1013.007812
# 5376 2021-08-29  83.125000  162.500000  1.031250  1.669771  1013.484375
# 5377 2021-08-30  77.578125  183.750000  0.937500  0.000000  1015.429688
# 5378 2021-08-31  87.421875  123.873900  0.796875  3.130668  1015.906250
#
#        n1이슬점 온도       n2습도   n2풍향      n2풍속  ...  ko_w최고 해면 기압  ko_w최저 해면기압  \
# 0     -9.167857  69.571429   27.5  0.607143  ...        1030.0       1025.9
# 1     -4.284375  77.772321   80.0  0.281250  ...        1030.0       1024.1
# 2     -0.572024  73.654762   40.0  0.285714  ...        1027.2       1023.0
# 3     -3.912500  55.000000  102.5  1.750000  ...        1025.6       1020.8
# 4     -6.006473  66.916667  115.0  0.531250  ...        1024.3       1019.4
# ...         ...        ...    ...       ...  ...           ...          ...
# 5374  20.028125  80.593750  350.0  0.937500  ...        1014.4       1010.3
# 5375  19.660938  75.125000  195.0  1.375000  ...        1015.5       1012.3
# 5376  19.915625  77.875000   42.5  1.218750  ...        1015.5       1012.0
# 5377  19.173437  73.281250  157.5  1.406250  ...        1016.8       1013.7
# 5378  18.273438  83.218750  110.0  1.062500  ...        1016.4       1010.5
#
#       ko_w평균 해면기압  ko_w평균 전운량  ko_w평균 중하층운량  ko_w평균 지면온도  ko_w안개 계속 시간  \
# 0     1028.333333    2.366667      0.400000     2.333333      0.000000
# 1     1026.900000    4.666667      1.366667     2.866667      0.000000
# 2     1025.466667    3.266667      1.966667     4.233333      0.000000
# 3     1023.300000    6.933333      4.666667     6.000000      0.000000
# 4     1021.766667    5.700000      3.266667     3.900000      0.000000
# ...           ...         ...           ...          ...           ...
# 5374  1012.766667    8.766667      5.566667    24.333333      0.166667
# 5375  1013.866667    7.200000      4.833333    25.933333      0.000000
# 5376  1013.366667    8.866667      5.433333    26.066667      0.000000
# 5377  1015.433333    8.433333      5.000000    26.100000      0.000000
# 5378  1014.000000    8.733333      4.533333    26.233333      0.000000
#
#            d1농도  check  target
# 0     24.555556      0       0
# 1     38.111111      0       1
# 2     63.444444      0       0
# 3     95.777778      1       1
# 4     64.666667      0       0
# ...         ...    ...     ...
# 5374  29.000000      0       0
# 5375  30.272727      0       0
# 5376  24.555556      0       0
# 5377  35.363636      0       0
# 5378  31.272727      0       0
#
# [5379 rows x 112 columns]

# %%
df_a = df_mm_m[df_mm_m['일시'] < '2019-01-01']

# %%
df_b = df_mm_m[df_mm_m['일시'] > '2019-12-31']

# %%
df_ml_m = pd.concat([df_a,df_b])

# %%
df_ml_m
# Out:
#              일시       n1습도        n1풍향      n1풍속     n1강수량       n1해면기압  \
# 0    2006-12-10  56.928571  230.000000  1.160714  0.000000  1028.351488
# 1    2006-12-11  65.468750  202.500000  2.062500  0.445600  1026.965625
# 2    2006-12-12  72.770833  179.274917  1.005952  0.000000  1024.439583
# 3    2006-12-13  62.916667  248.750000  1.416667  0.000000  1023.255208
# 4    2006-12-14  60.915179  167.500000  0.805804  0.000000  1021.968527
# ...         ...        ...         ...       ...       ...          ...
# 5374 2021-08-27  82.468750  111.250000  0.906250  0.880792  1011.759375
# 5375 2021-08-28  77.921875  115.000000  1.500000  0.000000  1013.007812
# 5376 2021-08-29  83.125000  162.500000  1.031250  1.669771  1013.484375
# 5377 2021-08-30  77.578125  183.750000  0.937500  0.000000  1015.429688
# 5378 2021-08-31  87.421875  123.873900  0.796875  3.130668  1015.906250
#
#        n1이슬점 온도       n2습도   n2풍향      n2풍속  ...  ko_w최고 해면 기압  ko_w최저 해면기압  \
# 0     -9.167857  69.571429   27.5  0.607143  ...        1030.0       1025.9
# 1     -4.284375  77.772321   80.0  0.281250  ...        1030.0       1024.1
# 2     -0.572024  73.654762   40.0  0.285714  ...        1027.2       1023.0
# 3     -3.912500  55.000000  102.5  1.750000  ...        1025.6       1020.8
# 4     -6.006473  66.916667  115.0  0.531250  ...        1024.3       1019.4
# ...         ...        ...    ...       ...  ...           ...          ...
# 5374  20.028125  80.593750  350.0  0.937500  ...        1014.4       1010.3
# 5375  19.660938  75.125000  195.0  1.375000  ...        1015.5       1012.3
# 5376  19.915625  77.875000   42.5  1.218750  ...        1015.5       1012.0
# 5377  19.173437  73.281250  157.5  1.406250  ...        1016.8       1013.7
# 5378  18.273438  83.218750  110.0  1.062500  ...        1016.4       1010.5
#
#       ko_w평균 해면기압  ko_w평균 전운량  ko_w평균 중하층운량  ko_w평균 지면온도  ko_w안개 계속 시간  \
# 0     1028.333333    2.366667      0.400000     2.333333      0.000000
# 1     1026.900000    4.666667      1.366667     2.866667      0.000000
# 2     1025.466667    3.266667      1.966667     4.233333      0.000000
# 3     1023.300000    6.933333      4.666667     6.000000      0.000000
# 4     1021.766667    5.700000      3.266667     3.900000      0.000000
# ...           ...         ...           ...          ...           ...
# 5374  1012.766667    8.766667      5.566667    24.333333      0.166667
# 5375  1013.866667    7.200000      4.833333    25.933333      0.000000
# 5376  1013.366667    8.866667      5.433333    26.066667      0.000000
# 5377  1015.433333    8.433333      5.000000    26.100000      0.000000
# 5378  1014.000000    8.733333      4.533333    26.233333      0.000000
#
#            d1농도  check  target
# 0     24.555556      0       0
# 1     38.111111      0       1
# 2     63.444444      0       0
# 3     95.777778      1       1
# 4     64.666667      0       0
# ...         ...    ...     ...
# 5374  29.000000      0       0
# 5375  30.272727      0       0
# 5376  24.555556      0       0
# 5377  35.363636      0       0
# 5378  31.272727      0       0
#
# [5014 rows x 112 columns]

# %%
# 머신러닝

# %%
y = df_ml_m['target']
x = df_ml_m.drop(['일시','check','target'], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier

# %%
from sklearn.metrics import classification_report, roc_auc_score

# %%
lr = LogisticRegression()
svc = SVC(probability=True)
rfc = RandomForestClassifier()
xg = XGBClassifier()
knn = KNeighborsClassifier()
lgbm = LGBMClassifier()

# %%
models = [lr, svc, rfc, xg, knn, lgbm]

# %%
for m in models:
    m.fit(x_train, y_train)
    pred = m.predict(x_test)
    preb = m.predict_proba(x_test)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.25      0.02      0.03        61
#
#     accuracy                           0.94      1003
#    macro avg       0.59      0.51      0.50      1003
# weighted avg       0.90      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8036267446312345
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.7636176951724618
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8157477985451255
# ====================================================================================================
# [09:45:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       942
#            1       0.58      0.11      0.19        61
#
#     accuracy                           0.94      1003
#    macro avg       0.76      0.55      0.58      1003
# weighted avg       0.92      0.94      0.92      1003
#
# --------------------------------------------------
# 0.8415126518394764
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.25      0.02      0.03        61
#
#     accuracy                           0.94      1003
#    macro avg       0.59      0.51      0.50      1003
# weighted avg       0.90      0.94      0.91      1003
#
# --------------------------------------------------
# 0.5111551982179527
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.50      0.05      0.09        61
#
#     accuracy                           0.94      1003
#    macro avg       0.72      0.52      0.53      1003
# weighted avg       0.91      0.94      0.92      1003
#
# --------------------------------------------------
# 0.8404684835195434
# ====================================================================================================

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
kfold = KFold()
for m in models:
    score = cross_val_score(m, x_train, y_train, cv=kfold)
    
    print(score)
    print(np.mean(score))
    print(np.std(score))
    print('='*100)
# Out:
# [0.94645081 0.93640898 0.94264339 0.94638404 0.94264339]
# 0.9429061219926522
# 0.003660919629701632
# ====================================================================================================
# [0.94894147 0.93640898 0.94264339 0.95012469 0.94763092]
# 0.945149889907858
# 0.00505897818033148
# ====================================================================================================
# [0.9501868  0.93640898 0.94139651 0.95012469 0.94763092]
# 0.9451495793517453
# 0.005417859712390253
# ====================================================================================================
# [09:46:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:46:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:46:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:46:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:46:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.94645081 0.93765586 0.94389027 0.94638404 0.94638404]
# 0.9441530047856697
# 0.0033916619771726325
# ====================================================================================================
# [0.94769614 0.93142145 0.94389027 0.95137157 0.94763092]
# 0.9444020707881604
# 0.006908094569620923
# ====================================================================================================
# [0.9501868  0.93391521 0.94139651 0.94638404 0.94763092]
# 0.9439026965587278
# 0.0057546070333138605
# ====================================================================================================

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# ko_s평균 풍속          0.026913
# d1농도               0.024897
# ko_e평균 증기압         0.024165
# ko_s평균 기온          0.022403
# ko_s평균 증기압         0.020753
# ko_w최저 해면기압        0.020701
# ko_e안개 계속 시간       0.018668
# ko_e평균 전운량         0.018645
# n1이슬점 온도           0.017843
# ko_s최대 순간 풍속 풍향    0.017562
# ko_s평균 지면온도        0.016740
# ko_e평균 현지기압        0.016382
# n4이슬점 온도           0.015802
# ko_e최저 기온          0.015733
# n7이슬점 온도           0.015585
# n6해면기압             0.014776
# n5이슬점 온도           0.014672
# ko_s최저 해면기압        0.014241
# ko_s평균 이슬점온도       0.014239
# n4습도               0.013460
# ko_s최대 풍향          0.013346
# n6이슬점 온도           0.013160
# ko_s최대 풍속 풍향       0.013157
# ko_s평균 현지기압        0.013104
# n6강수량              0.011906
# ko_w평균 이슬점온도       0.011740
# n7강수량              0.011596
# ko_e평균 해면기압        0.011307
# n3이슬점 온도           0.011166
# n6풍속               0.010935
# n6풍향               0.010863
# ko_w평균 지면온도        0.010604
# n4풍향               0.010580
# ko_s평균 중하층운량       0.010456
# n3해면기압             0.010250
# n1해면기압             0.010199
# n5강수량              0.010148
# ko_e최대 풍속          0.009900
# ko_e평균 중하층운량       0.009837
# ko_w안개 계속 시간       0.009619
# n5해면기압             0.009612
# n6습도               0.009471
# ko_w평균 해면기압        0.009217
# n7풍속               0.009171
# ko_w평균 기온          0.009012
# ko_w평균 상대습도        0.008967
# n7습도               0.008938
# ko_s최고 해면 기압       0.008912
# ko_s풍정합            0.008644
# ko_w최대 풍향          0.008620
# ko_s일강수량           0.008493
# ko_e최대 순간 풍속 풍향    0.008474
# n2풍속               0.008366
# n2해면기압             0.008347
# n3습도               0.008331
# ko_s최대 순간풍속        0.008273
# n1습도               0.008248
# ko_w평균 전운량         0.008246
# ko_e최대 순간풍속        0.007890
# ko_e일강수량           0.007715
# dtype: float32

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

std.fit(x_train)
x_train_std = std.transform(x_train)
x_test_std = std.transform(x_test)

# %%
models = [lr, svc, rfc, xg, knn, lgbm]

for m in models:
    m.fit(x_train_std, y_train)
    pred = m.predict(x_test_std)
    preb = m.predict_proba(x_test_std)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       942
#            1       0.57      0.13      0.21        61
#
#     accuracy                           0.94      1003
#    macro avg       0.76      0.56      0.59      1003
# weighted avg       0.92      0.94      0.92      1003
#
# --------------------------------------------------
# 0.8525634332254359
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8054192335804532
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.94      1003
#    macro avg       0.47      0.50      0.48      1003
# weighted avg       0.88      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8344645156799276
# ====================================================================================================
# [09:46:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       942
#            1       0.58      0.11      0.19        61
#
#     accuracy                           0.94      1003
#    macro avg       0.76      0.55      0.58      1003
# weighted avg       0.92      0.94      0.92      1003
#
# --------------------------------------------------
# 0.8415126518394764
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       942
#            1       0.50      0.08      0.14        61
#
#     accuracy                           0.94      1003
#    macro avg       0.72      0.54      0.55      1003
# weighted avg       0.92      0.94      0.92      1003
#
# --------------------------------------------------
# 0.7065364936827817
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       942
#            1       0.43      0.05      0.09        61
#
#     accuracy                           0.94      1003
#    macro avg       0.69      0.52      0.53      1003
# weighted avg       0.91      0.94      0.91      1003
#
# --------------------------------------------------
# 0.8457589363405381
# ====================================================================================================

# %%
pd.Series(xg.feature_importances_, x.columns).sort_values(ascending=False).head(60)
# Out:
# d1농도               0.062298
# ko_s최저 기온          0.042143
# ko_s평균 이슬점온도       0.025625
# ko_w최고 기온          0.024405
# n6이슬점 온도           0.024340
# ko_w일강수량           0.023279
# n5이슬점 온도           0.023239
# ko_s평균 기온          0.022305
# n4습도               0.021381
# ko_s최대 순간 풍속 풍향    0.020720
# n7강수량              0.019638
# ko_s안개 계속 시간       0.019220
# n1이슬점 온도           0.018917
# n3강수량              0.018509
# ko_e안개 계속 시간       0.018383
# n1강수량              0.017723
# ko_e평균 중하층운량       0.017201
# ko_e일강수량           0.016809
# ko_s최대 풍향          0.016226
# n4이슬점 온도           0.015902
# n3풍향               0.015372
# ko_e평균 이슬점온도       0.015314
# n5해면기압             0.014439
# ko_w최저 기온          0.012660
# n4풍향               0.012554
# n6해면기압             0.012535
# ko_w안개 계속 시간       0.011375
# n7해면기압             0.011088
# n2이슬점 온도           0.010868
# n1풍향               0.010397
# ko_e최대 풍향          0.009965
# ko_w평균 풍속          0.009785
# n6풍속               0.009529
# ko_e평균 전운량         0.009528
# ko_w최저 해면기압        0.009471
# ko_w최대 풍속 풍향       0.009367
# n2해면기압             0.009151
# ko_s최대 순간풍속        0.008801
# ko_e평균 해면기압        0.008716
# ko_e평균 현지기압        0.008467
# ko_s최대 풍속 풍향       0.008350
# n2풍속               0.008263
# n6풍향               0.008203
# ko_e최대 순간 풍속 풍향    0.008047
# ko_s일강수량           0.007955
# ko_s평균 현지기압        0.007761
# ko_e평균 풍속          0.007697
# n4해면기압             0.007595
# ko_e최저 해면기압        0.007406
# n7풍향               0.007335
# ko_s평균 풍속          0.007302
# ko_s평균 중하층운량       0.007180
# ko_e최대 풍속 풍향       0.007136
# n1해면기압             0.007039
# ko_e최저 기온          0.006911
# ko_e최대 순간풍속        0.006899
# n6습도               0.006736
# n7습도               0.006658
# ko_e평균 지면온도        0.006522
# ko_w평균 현지기압        0.006448
# dtype: float32

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.3)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\goejt\\anaconda3\\Lib\\site-packages\\~klearn\\decomposition\\_cdnmf_fast.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: joblib>=0.11 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Collecting scikit-learn>=1.0.1
#   Downloading scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Installing collected packages: scikit-learn, imbalanced-learn, imblearn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn) (1.20.3)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\goejt\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.9.0

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=100)
x_train_std_sm, y_train_sm = smote.fit_resample(x_train_std, y_train)

# %%
y_train_sm.value_counts()
# Out:
# 0    3791
# 1    3791
# Name: target, dtype: int64

# %%
for m in models:
    m.fit(x_train_std_sm, y_train_sm)
    pred = m.predict(x_test_std)
    preb = m.predict_proba(x_test_std)
    
    print(classification_report(y_test, pred))
    print('-'*50)
    print(roc_auc_score(y_test, preb[:,1]))
    print('='*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89       942
#            1       0.19      0.66      0.30        61
#
#     accuracy                           0.81      1003
#    macro avg       0.58      0.74      0.59      1003
# weighted avg       0.93      0.81      0.85      1003
#
# --------------------------------------------------
# 0.8548954091399534
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95       942
#            1       0.29      0.43      0.34        61
#
#     accuracy                           0.90      1003
#    macro avg       0.63      0.68      0.65      1003
# weighted avg       0.92      0.90      0.91      1003
#
# --------------------------------------------------
# 0.8251975218405206
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       942
#            1       0.22      0.13      0.16        61
#
#     accuracy                           0.92      1003
#    macro avg       0.58      0.55      0.56      1003
# weighted avg       0.90      0.92      0.91      1003
#
# --------------------------------------------------
# 0.8199331732275242
# ====================================================================================================
# [09:46:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       942
#            1       0.42      0.21      0.28        61
#
#     accuracy                           0.93      1003
#    macro avg       0.68      0.60      0.62      1003
# weighted avg       0.92      0.93      0.92      1003
#
# --------------------------------------------------
# 0.8465072569698235
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.98      0.64      0.77       942
#            1       0.12      0.77      0.21        61
#
#     accuracy                           0.65      1003
#    macro avg       0.55      0.71      0.49      1003
# weighted avg       0.93      0.65      0.74      1003
#
# --------------------------------------------------
# 0.7499216873760051
# ====================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       942
#            1       0.29      0.16      0.21        61
#
#     accuracy                           0.92      1003
#    macro avg       0.62      0.57      0.58      1003
# weighted avg       0.91      0.92      0.91      1003
#
# --------------------------------------------------
# 0.8045838989245067
# ====================================================================================================

# %%
x
# Out:
#            n1습도        n1풍향      n1풍속     n1강수량       n1해면기압   n1이슬점 온도  \
# 0     56.928571  230.000000  1.160714  0.000000  1028.351488  -9.167857
# 1     65.468750  202.500000  2.062500  0.445600  1026.965625  -4.284375
# 2     72.770833  179.274917  1.005952  0.000000  1024.439583  -0.572024
# 3     62.916667  248.750000  1.416667  0.000000  1023.255208  -3.912500
# 4     60.915179  167.500000  0.805804  0.000000  1021.968527  -6.006473
# ...         ...         ...       ...       ...          ...        ...
# 4765  59.703125  218.750000  1.843750  0.000000  1023.760937  -9.764062
# 4766  73.593750  150.000000  1.765625  0.478187  1026.767187  -4.006250
# 4767  71.625000  152.098983  1.906250  0.445600  1025.548437  -1.056250
# 4768  69.750000  295.000000  3.625000  1.598263  1023.862500  -4.415625
# 4769  52.031250  262.500000  4.046875  0.000000  1034.529687 -16.756250
#
#            n2습도   n2풍향      n2풍속     n2강수량  ...  n3평균 증기압  n3평균 현지기압  \
# 0     69.571429   27.5  0.607143  0.000000  ...       6.1     1024.8
# 1     77.772321   80.0  0.281250  0.000000  ...       7.2     1023.6
# 2     73.654762   40.0  0.285714  0.000000  ...       7.9     1022.6
# 3     55.000000  102.5  1.750000  0.000000  ...       9.0     1020.7
# 4     66.916667  115.0  0.531250  0.530917  ...       7.5     1018.9
# ...         ...    ...       ...       ...  ...       ...        ...
# 4765  67.312500   80.0  1.562500  0.000000  ...       5.4     1023.0
# 4766  78.718750  125.0  0.875000  0.275000  ...       6.0     1025.7
# 4767  82.500000  177.5  0.812500  0.000000  ...      11.6     1020.3
# 4768  76.812500  187.5  1.875000  1.289723  ...      10.4     1021.7
# 4769  55.000000  232.5  1.655911  0.000000  ...       4.6     1031.3
#
#       n3최고 해면 기압  n3최저 해면기압  n3평균 해면기압  n3평균 전운량  n3평균 중하층운량  n3평균 지면온도  \
# 0         1028.6     1026.2     1027.4       7.8         6.8        7.7
# 1         1027.6     1024.4     1026.1       8.9         5.9        8.3
# 2         1026.6     1024.0     1025.1       9.5         5.6       10.2
# 3         1025.3     1021.0     1023.2       8.5         6.1       10.1
# 4         1023.8     1018.7     1021.5       7.9         3.0        8.8
# ...          ...        ...        ...       ...         ...        ...
# 4765      1028.1     1021.8     1025.6       8.6         8.6        6.2
# 4766      1030.2     1027.1     1028.3       4.8         3.8        7.2
# 4767      1028.3     1019.5     1022.9       9.6         7.0        9.3
# 4768      1029.8     1020.7     1024.2       8.5         7.1       10.8
# 4769      1036.4     1029.7     1033.9       8.6         8.6        5.4
#
#       n3안개 계속 시간       d1농도
# 0            0.0  24.555556
# 1            0.0  38.111111
# 2            0.0  63.444444
# 3            0.0  95.777778
# 4            0.0  64.666667
# ...          ...        ...
# 4765         0.0  25.230769
# 4766         0.0  35.923077
# 4767         0.0  35.923077
# 4768         0.0  27.307692
# 4769         0.0  21.307692
#
# [4770 rows x 109 columns]

# %%
from sklearn.model_selection import GridSearchCV
param = { 'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]}

xg_gv = XGBClassifier()
grid = GridSearchCV(xg_gv, param_grid=param, refit=True, verbose=False)
grid.fit(x_train_std_sm, y_train_sm)
# Out:
# [09:47:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:48:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:51:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:53:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
# [11:35:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:35:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:35:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:35:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:35:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:35:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:36:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:37:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:38:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:39:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_est...jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 1.5, 2, 5], 'max_depth': [3, 4, 5],
#                          'min_child_weight': [1, 5, 10],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=False)

# %%
grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 1,
#  'max_depth': 5,
#  'min_child_weight': 1,
#  'subsample': 0.6}

# %%
grid.best_score_
# Out:
# 0.9771854775169017

# %%
xg_g = XGBClassifier('colsample_bytree'= 0.8,
 'gamma'= 1,
 'max_depth'= 5,
 'min_child_weight'= 1,
 'subsample'= 0.6)

xg_g.fit(x_train_std_sm, y_train_sm)
pred = rfc.predict(x_test_std)
print(classification_report(y_test, pred))
# Out:
#   File "C:\Users\goejt\AppData\Local\Temp/ipykernel_36888/2457593655.py", line 1
#     xg_g = XGBClassifier('colsample_bytree'= 0.8,
#                          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
